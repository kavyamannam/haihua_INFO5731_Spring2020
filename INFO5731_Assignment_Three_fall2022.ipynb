# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyamannam/haihua_INFO5731_Spring2020/blob/main/INFO5731_Assignment_Three_fall2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
# Write your code here
#installing selenium package
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:14 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [2,225 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,561 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [22.8 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,065 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,138 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,492 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1,262 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,303 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [29.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,336 kB]
# Fetched 16.7 MB in 5s (3,103 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 5 not upgraded.
# Need to get 95.1 MB of archives.
# After this operation, 319 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 107.0.5304.87-0ubuntu11.18.04.1 [1,158 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 107.0.5304.87-0ubuntu11.18.04.1 [83.1 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 107.0.5304.87-0ubuntu11.18.04.1 [5,260 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 107.0.5304.87-0ubuntu11.18.04.1 [5,570 kB]
# Fetched 95.1 MB in 5s (19.6 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 123991 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_107.0.5304.87-0ubuntu11.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (107.0.5304.87-0ubuntu11.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_107.0.5304.87-0ubuntu11.18.04.1_amd64.deb ...
# Unpacking chromium-browser (107.0.5304.87-0ubuntu11.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_107.0.5304.87-0ubuntu11.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (107.0.5304.87-0ubuntu11.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_107.0.5304.87-0ubuntu11.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (107.0.5304.87-0ubuntu11.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (107.0.5304.87-0ubuntu11.18.04.1) ...
# Setting up chromium-browser (107.0.5304.87-0ubuntu11.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (107.0.5304.87-0ubuntu11.18.04.1) ...
# Setting up chromium-browser-l10n (107.0.5304.87-0ubuntu11.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting selenium
#   Downloading selenium-4.6.0-py3-none-any.whl (5.2 MB)
#      |████████████████████████████████| 5.2 MB 4.9 MB/s
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.7/dist-packages (from selenium) (2022.9.24)
# Collecting urllib3[socks]~=1.26
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 54.5 MB/s
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      |████████████████████████████████| 384 kB 57.3 MB/s
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (22.1.0)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.0.4-py3-none-any.whl (14 kB)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.9 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (4.1.1)
# Installing collected packages: sniffio, outcome, h11, exceptiongroup, async-generator, wsproto, urllib3, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.12 which is incompatible.
# Successfully installed async-generator-1.10 exceptiongroup-1.0.4 h11-0.14.0 outcome-1.2.0 selenium-4.6.0 sniffio-1.3.0 trio-0.22.0 trio-websocket-0.9.2 urllib3-1.26.12 wsproto-1.2.0

# %%
from selenium import webdriver #importing selenium package
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv'
title_array = []
review_array = []
driver.get(link)
for num in range(4):
  driver.find_element(By.CLASS_NAME,"ipl-load-more__button").click()
  time.sleep(5)
  listOfTitle = driver.find_elements(By.CLASS_NAME, "title")
  listOfReviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(listOfTitle, listOfReviews):
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
df = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# Length of data frame is 124
#                                                  Title  \
# 0                             Perfect in every aspect.
# 1    A psychological study, rather than a superhero...
# 2                      Went for a second time to watch
# 3             JUST AMAZING. How does this movie exist.
# 4    Outstanding movie with a haunting performance ...
# ..                                                 ...
# 119  Masterpiece *Movie Of the Year* Best Actor - J...
# 120  The Joker is supposed to be a diabolical maste...
# 121                               Better if didn't saw
# 122                  Why Todd Phillipps Made This Film
# 123  A total letdown ... a hybrid film bordering be...
#
#                                                 Review
# 0    Truly a masterpiece, The Best Hollywood film o...
# 1    I have seen Joker yesterday at Venice an early...
# 2    I get why some people hate this . It's because...
# 3    Let me start off by saying if Joaquin Phoneix ...
# 4    Every once in a while a movie comes, that trul...
# ..                                                 ...
# 119  Wow I honestly gotta tell you, it's one of the...
# 120
# 121  Disturbing. Just got out of the movie. My humo...
# 122  You will notice the far left journalists: the ...
# 123  Ugghhh how could I be so wrong in my assessmen...
#
# [124 rows x 2 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package extended_omw to /root/nltk_data...
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        | Downloading package omw-1.4 to /root/nltk_data...
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pe08 to /root/nltk_data...
#        |   Unzipping corpora/pe08.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        | Downloading package wordnet2021 to /root/nltk_data...
#        | Downloading package wordnet31 to /root/nltk_data...
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        |
#      Done downloading collection all
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
df['Lower Case'] = df['Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
df['Removal of Punctuation'] = df['Lower Case'].str.replace('[^\w\s]','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
import re
df['Removal of Special Characters'] = df['Removal of Punctuation'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = stopwords.words('english')
df['Stopwords Removal'] = df['Removal of Punctuation'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from textblob import TextBlob
df['Spelling Correction'] = df['Stopwords Removal'].apply(lambda x: str(TextBlob(x).correct()))

# %%
import nltk
nltk.download('punkt')
df['Tokenization'] = df['Spelling Correction'].apply(lambda x: TextBlob(x).words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['After Stemming'] = df['Tokenization'].apply(lambda x: " ".join([st.stem(word) for word in x]))

# %%
from textblob import Word
import nltk
nltk.download('wordnet')

df['After Lemmatization'] = df['After Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df.to_csv('/content/sample_data/reviwes.csv',index=False)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize

words_sentence = []
for sentence in df['After Lemmatization']:
  words_sentence.append(word_tokenize(sentence))
aftercleaning = [x for x in words_sentence if x != []]
iterations = list(itertools.chain.from_iterable(aftercleaning))

# %%
tri_grams = nltk.trigrams(iterations)
frequency_dist = nltk.FreqDist(tri_grams)
frequency_dist
# Out:
# FreqDist({('taxi', 'driver', 'king'): 6, ('driver', 'king', 'comedi'): 6, ('director', 'told', 'phillip'): 5, ('dark', 'knight', 'trilog'): 4, ('robert', 'de', 'no'): 4, ('perform', 'joaquin', 'phoenix'): 4, ('upon', 'time', 'hollywood'): 3, ('new', 'york', 'citi'): 3, ('joaquin', 'phoenix', 'play'): 3, ('one', 'best', 'move'): 3, ...})

# %%
from collections import Counter
bi_grams = nltk.bigrams(iterations)
frequency_dist = nltk.FreqDist(bi_grams)
bi_grams_dict = dict(frequency_dist)
for word in bi_grams_dict:
  print( str(word) + ':' + str(bi_grams_dict[word] / iterations.count(word[0])))
# Out:
# Streaming output truncated to the last 5000 lines.
# ('day', 'view'):0.1111111111111111
# ('view', 'oper'):0.2
# ('oper', 'whole'):0.3333333333333333
# ('whole', 'point'):0.125
# ('point', 'movi'):0.06666666666666667
# ('movi', 'bring'):0.00558659217877095
# ('bring', 'attent'):0.1
# ('attent', 'mental'):0.25
# ('ill', 'ill'):0.045454545454545456
# ('ill', 'one'):0.045454545454545456
# ('one', 'better'):0.017241379310344827
# ('better', 'name'):0.043478260869565216
# ('name', 'bigger'):0.16666666666666666
# ('issu', 'mental'):0.2
# ('ill', 'film'):0.045454545454545456
# ('film', 'bare'):0.007352941176470588
# ('bare', 'focus'):0.3333333333333333
# ('focus', 'lack'):0.25
# ('lack', 'qualiti'):0.14285714285714285
# ('qualiti', 'mental'):0.2
# ('mental', 'healthcar'):0.02857142857142857
# ('healthcar', 'film'):1.0
# ('film', 'complet'):0.007352941176470588
# ('complet', 'discredit'):0.14285714285714285
# ('discredit', 'messag'):1.0
# ('messag', 'one'):0.1111111111111111
# ('one', 'dimens'):0.017241379310344827
# ('dimens', 'deduct'):1.0
# ('deduct', 'world'):0.6666666666666666
# ('world', 'charact'):0.0625
# ('charact', 'inhabit'):0.018518518518518517
# ('inhabit', 'seem'):1.0
# ('seem', 'gothic'):0.043478260869565216
# ('gothic', 'citizen'):0.08333333333333333
# ('citizen', 'entir'):0.5
# ('entir', 'univers'):0.14285714285714285
# ('univers', 'matter'):0.1
# ('matter', 'exist'):0.3333333333333333
# ('exist', 'put'):0.14285714285714285
# ('put', 'arthur'):0.07692307692307693
# ('arthur', 'consid'):0.02127659574468085
# ('consid', 'film'):0.125
# ('film', 'isn'):0.007352941176470588
# ('isn', 'told'):0.08333333333333333
# ('told', 'arthur'):0.05263157894736842
# ('arthur', 'perspect'):0.02127659574468085
# ('perspect', 'blatantli'):0.25
# ('blatantli', 'stupid'):1.0
# ('stupid', 'deduct'):0.25
# ('world', 'reason'):0.0625
# ('reason', 'peopl'):0.2
# ('peopl', 'like'):0.043478260869565216
# ('like', 'much'):0.017241379310344827
# ('much', 'sad'):0.03125
# ('sad', 'corpor'):0.14285714285714285
# ('corpor', 'slave'):0.5
# ('slave', 'especi'):1.0
# ('especi', 'youth'):0.16666666666666666
# ('youth', 'current'):0.5
# ('current', 'indoctrin'):0.5
# ('indoctrin', 'unconsci'):1.0
# ('unconsci', 'trick'):1.0
# ('trick', 'believ'):1.0
# ('believ', 'part'):0.09090909090909091
# ('part', 'bigger'):0.07692307692307693
# ('bigger', 'caus'):0.3333333333333333
# ('caus', 'realli'):0.14285714285714285
# ('realli', 'sit'):0.023809523809523808
# ('sit', 'come'):0.3333333333333333
# ('come', 'chair'):0.05263157894736842
# ('chair', 'review'):1.0
# ('review', 'joke'):0.07407407407407407
# ('joke', 'new'):0.007575757575757576
# ('new', 'worker'):0.07142857142857142
# ('worker', 'great'):0.25
# ('great', 'film'):0.05263157894736842
# ('film', 'critic'):0.007352941176470588
# ('critic', 'anthoni'):0.1111111111111111
# ('anthoni', 'lane'):1.0
# ('lane', 'call'):0.5
# ('call', 'lurid'):0.16666666666666666
# ('lurid', 'spectacl'):1.0
# ('spectacl', 'miserablist'):0.5
# ('miserablist', 'manifesto'):1.0
# ('manifesto', 'limb'):0.5
# ('limb', 'user'):0.5
# ('user', 'review'):0.5
# ('review', 'give'):0.037037037037037035
# ('give', 'away'):0.05263157894736842
# ('away', 'plot'):0.125
# ('plot', 'wont'):0.047619047619047616
# ('wont', 'reap'):0.2
# ('reap', 'film'):1.0
# ('far', 'databas'):0.045454545454545456
# ('databas', 'provid'):1.0
# ('provid', 'except'):0.3333333333333333
# ('except', 'lengthi'):0.25
# ('lengthi', 'explan'):1.0
# ('explan', 'bewild'):1.0
# ('bewild', 'plot'):1.0
# ('twist', 'possibl'):0.09090909090909091
# ('possibl', 'motiv'):0.16666666666666666
# ('motiv', 'joaquin'):0.25
# ('phoenix', 'disturb'):0.014084507042253521
# ('disturb', 'portray'):0.058823529411764705
# ('portray', 'psychopath'):0.14285714285714285
# ('psychopath', 'killer'):0.16666666666666666
# ('killer', 'mani'):0.2
# ('mani', 'mental'):0.030303030303030304
# ('mental', 'disord'):0.02857142857142857
# ('disord', 'imposs'):1.0
# ('imposs', 'name'):0.25
# ('name', 'watch'):0.16666666666666666
# ('watch', 'film'):0.047619047619047616
# ('film', 'like'):0.029411764705882353
# ('like', 'subject'):0.017241379310344827
# ('subject', 'twohour'):0.5
# ('twohour', 'nightmarenot'):1.0
# ('nightmarenot', 'anyth'):1.0
# ('anyth', 'viewer'):0.06666666666666667
# ('viewer', 'brain'):0.125
# ('brain', 'matter'):0.5
# ('matter', 'mind'):0.3333333333333333
# ('mind', 'main'):0.08333333333333333
# ('main', 'characterunless'):0.09090909090909091
# ('characterunless', 'remind'):1.0
# ('remind', 'take'):0.2
# ('take', 'bed'):0.04
# ('bed', 'writerdirector'):1.0
# ('writerdirector', 'attempt'):0.5
# ('attempt', 'cash'):0.3333333333333333
# ('cash', 'nation'):0.5
# ('nation', 'cynic'):1.0
# ('cynic', 'although'):0.5
# ('although', 'movi'):0.25
# ('movi', 'pretend'):0.00558659217877095
# ('pretend', 'side'):1.0
# ('side', 'poor'):0.3333333333333333
# ('poor', 'abus'):0.16666666666666666
# ('abus', 'downtrodden'):0.14285714285714285
# ('downtrodden', 'also'):1.0
# ('also', 'suggest'):0.041666666666666664
# ('suggest', 'evil'):0.3333333333333333
# ('evil', 'medium'):0.16666666666666666
# ('medium', 'complac'):0.25
# ('complac', 'rich'):1.0
# ('rich', 'law'):0.14285714285714285
# ('law', 'enforc'):1.0
# ('enforc', 'social'):1.0
# ('social', 'worker'):0.16666666666666666
# ('worker', 'everi'):0.25
# ('everi', 'sane'):0.07142857142857142
# ('sane', 'person'):1.0
# ('person', 'gothic'):0.06666666666666667
# ('read', 'new'):0.3333333333333333
# ('citi', 'part'):0.1
# ('part', 'evil'):0.07692307692307693
# ('evil', 'cabal'):0.16666666666666666
# ('cabal', 'taken'):1.0
# ('taken', 'control'):0.25
# ('control', 'world'):1.0
# ('world', 'case'):0.0625
# ('case', 'aerial'):0.5
# ('aerial', 'killer'):1.0
# ('killer', 'john'):0.2
# ('john', 'wayn'):1.0
# ('wayn', 'gay'):0.07142857142857142
# ('gay', 'didn'):1.0
# ('didn', 'sound'):0.09090909090909091
# ('sound', 'death'):0.1111111111111111
# ('death', 'knell'):0.5
# ('knell', 'profession'):1.0
# ('profession', 'clown'):1.0
# ('clown', 'movi'):0.0625
# ('tri', 'best'):0.07142857142857142
# ('best', 'good'):0.03125
# ('good', 'film'):0.034482758620689655
# ('film', 'made'):0.007352941176470588
# ('made', 'insan'):0.058823529411764705
# ('insan', 'take'):0.16666666666666666
# ('take', 'asylum'):0.04
# ('asylum', 'never'):1.0
# ('never', 'much'):0.04
# ('much', 'cold'):0.03125
# ('cold', 'calcul'):1.0
# ('calcul', 'cash'):1.0
# ('cash', 'mind'):0.5
# ('mind', 'littl'):0.08333333333333333
# ('littl', 'insight'):0.1111111111111111
# ('insight', 'insan'):0.5
# ('insan', 'happen'):0.16666666666666666
# ('happen', 'dislik'):0.07142857142857142
# ('film', 'heartili'):0.007352941176470588
# ('heartili', 'anyth'):1.0
# ('anyth', 'give'):0.06666666666666667
# ('seen', 'past'):0.043478260869565216
# ('past', 'decad'):0.125
# ('decad', 'anthoni'):0.14285714285714285
# ('lane', 'said'):0.5
# ('said', 'septemb'):0.16666666666666666
# ('septemb', '2019new'):1.0
# ('2019new', 'worker'):1.0
# ('worker', 'review'):0.25
# ('review', 'realiz'):0.037037037037037035
# ('realiz', 'equal'):0.3333333333333333
# ('equal', 'vent'):0.3333333333333333
# ('vent', 'inordin'):1.0
# ('inordin', 'wrath'):1.0
# ('wrath', 'toward'):1.0
# ('toward', 'fall'):0.14285714285714285
# ('fall', 'straight'):0.16666666666666666
# ('straight', 'trap'):1.0
# ('trap', 'outrag'):1.0
# ('outrag', 'mere'):0.5
# ('mere', 'prove'):0.3333333333333333
# ('prove', 'attent'):0.3333333333333333
# ('attent', 'engag'):0.25
# ('engag', 'ask'):0.16666666666666666
# ('ask', 'presid'):0.3333333333333333
# ('presid', 'unit'):1.0
# ('unit', 'state'):1.0
# ('state', 'joaquin'):0.25
# ('play', 'joaquin'):0.07142857142857142
# ('phoenix', 'bore'):0.014084507042253521
# ('bore', 'twist'):0.05555555555555555
# ('twist', 'sick'):0.09090909090909091
# ('sick', 'piec'):0.125
# ('piec', 'cap'):0.4
# ('cap', 'one'):0.25
# ('one', 'done'):0.017241379310344827
# ('done', 'movi'):0.1111111111111111
# ('movi', 'mani'):0.00558659217877095
# ('mani', 'aspect'):0.030303030303030304
# ('aspect', 'mirror'):0.25
# ('mirror', 'societi'):0.3333333333333333
# ('societi', 'viewer'):0.038461538461538464
# ('viewer', 'way'):0.125
# ('way', 'develop'):0.02631578947368421
# ('develop', 'societi'):0.25
# ('societi', 'basic'):0.038461538461538464
# ('basic', 'virtu'):0.5
# ('virtu', 'splendid'):1.0
# ('splendid', 'perform'):1.0
# ('perform', 'joaquin'):0.08888888888888889
# ('phoenix', 'beauti'):0.014084507042253521
# ('beauti', 'cinematographi'):0.25
# ('cinematographi', 'sure'):0.05
# ('sure', 'ignor'):0.05555555555555555
# ('ignor', 'comic'):0.14285714285714285
# ('book', 'charact'):0.07692307692307693
# ('charact', 'feel'):0.018518518518518517
# ('feel', 'film'):0.02564102564102564
# ('film', 'portrait'):0.007352941176470588
# ('portrait', 'larg'):0.5
# ('larg', 'cri'):0.3333333333333333
# ('cri', 'sin'):1.0
# ('sin', 'mayb'):1.0
# ('mayb', 'much'):0.08333333333333333
# ('much', 'taxi'):0.03125
# ('driver', 'ambit'):0.058823529411764705
# ('ambit', 'explain'):1.0
# ('explain', 'show'):0.3333333333333333
# ('show', 'everyth'):0.058823529411764705
# ('everyth', 'angri'):0.1111111111111111
# ('angri', 'frustrat'):0.25
# ('frustrat', 'refug'):1.0
# ('refug', 'fall'):1.0
# ('fall', 'mind'):0.16666666666666666
# ('mind', 'soul'):0.08333333333333333
# ('soul', 'suggest'):1.0
# ('suggest', 'real'):0.3333333333333333
# ('real', 'sen'):0.08333333333333333
# ('sen', 'incred'):0.14285714285714285
# ('incred', 'short'):0.1
# ('short', 'form'):0.16666666666666666
# ('form', 'manifesto'):0.25
# ('manifesto', 'sort'):0.5
# ('sort', 'mirror'):0.5
# ('mirror', 'viewer'):0.3333333333333333
# ('viewer', 'mental'):0.125
# ('health', 'issu'):0.25
# ('issu', 'problem'):0.2
# ('problem', 'societi'):0.07692307692307693
# ('societi', 'view'):0.038461538461538464
# ('view', 'upon'):0.2
# ('upon', 'handl'):0.2
# ('handl', 'deduct'):0.5
# ('deduct', 'deterior'):0.3333333333333333
# ('deterior', 'mind'):1.0
# ('mind', 'realli'):0.08333333333333333
# ('realli', 'comic'):0.023809523809523808
# ('movi', 'quit'):0.00558659217877095
# ('quit', 'someth'):0.07692307692307693
# ('someth', 'even'):0.07692307692307693
# ('even', 'score'):0.037037037037037035
# ('score', 'would'):0.045454545454545456
# ('would', 'approv'):0.02564102564102564
# ('approv', 'reckon'):1.0
# ('reckon', 'talk'):1.0
# ('talk', 'perform'):0.08333333333333333
# ('realli', 'surpris'):0.023809523809523808
# ('surpris', 'never'):0.16666666666666666
# ('never', 'thought'):0.12
# ('thought', 'id'):0.07692307692307693
# ('id', 'see'):0.2
# ('see', 'anoth'):0.030303030303030304
# ('anoth', 'joke'):0.14285714285714285
# ('joke', 'characteractor'):0.007575757575757576
# ('characteractor', 'come'):1.0
# ('come', 'close'):0.10526315789473684
# ('close', 'heath'):0.125
# ('ledger', 'decad'):0.058823529411764705
# ('decad', 'ago'):0.14285714285714285
# ('ago', 'question'):0.3333333333333333
# ('question', 'differ'):0.3333333333333333
# ('differ', 'time'):0.058823529411764705
# ('time', 'guess'):0.017543859649122806
# ('guess', 'new'):0.3333333333333333
# ('new', 'joke'):0.07142857142857142
# ('movi', 'rather'):0.00558659217877095
# ('rather', 'stori'):0.16666666666666666
# ('stori', 'keep'):0.02702702702702703
# ('keep', 'foot'):0.125
# ('foot', 'joaquin'):0.3333333333333333
# ('joaquin', 'mesmer'):0.016666666666666666
# ('mesmer', 'would'):0.2
# ('would', 'surpris'):0.02564102564102564
# ('surpris', 'got'):0.16666666666666666
# ('got', 'oscar'):0.14285714285714285
# ('oscar', 'sinc'):0.043478260869565216
# ('sinc', 'nomin'):0.14285714285714285
# ('nomin', 'came'):0.07692307692307693
# ('came', 'know'):0.3333333333333333
# ('know', 'possibl'):0.058823529411764705
# ('possibl', 'everyon'):0.16666666666666666
# ('everyon', 'watch'):0.058823529411764705
# ('watch', 'expect'):0.023809523809523808
# ('expect', 'get'):0.045454545454545456
# ('get', 'nomin'):0.02040816326530612
# ('nomin', 'movi'):0.07692307692307693
# ('movi', 'would'):0.0111731843575419
# ('would', 'get'):0.05128205128205128
# ('get', '11'):0.02040816326530612
# ('11', 'nod'):0.25
# ('nod', 'though'):0.2
# ('though', 'quit'):0.125
# ('quit', 'unexpect'):0.07692307692307693
# ('unexpect', 'seem'):1.0
# ('seem', 'movi'):0.043478260869565216
# ('movi', 'drama'):0.00558659217877095
# ('drama', 'rather'):0.1111111111111111
# ('rather', 'thrill'):0.16666666666666666
# ('thrill', 'park'):0.2
# ('park', 'ride'):1.0
# ('ride', 'doesn'):0.25
# ('doesn', 'mean'):0.18181818181818182
# ('mean', 'one'):0.07692307692307693
# ('one', 'thing'):0.034482758620689655
# ('thing', 'big'):0.047619047619047616
# ('big', 'fan'):0.3333333333333333
# ('fan', 'you'):0.14285714285714285
# ('you', 'admit'):0.125
# ('admit', 'realli'):0.3333333333333333
# ('realli', 'like'):0.023809523809523808
# ('like', 'even'):0.017241379310344827
# ('even', 'near'):0.037037037037037035
# ('near', 'du'):0.25
# ('du', 'dont'):1.0
# ('dont', 'compar'):0.03571428571428571
# ('compar', 'someth'):0.25
# ('someth', 'comic'):0.07692307692307693
# ('book', 'like'):0.07692307692307693
# ('like', 'friend'):0.017241379310344827
# ('friend', 'parasit'):0.5
# ('parasit', 'anoth'):1.0
# ('anoth', 'favorit'):0.14285714285714285
# ('favorit', 'mine'):0.5
# ('mine', '2019'):1.0
# ('2019', 'enjoy'):0.14285714285714285
# ('enjoy', 'great'):0.08333333333333333
# ('movi', 'land'):0.00558659217877095
# ('land', 'blind'):0.5
# ('blind', 'need'):1.0
# ('need', 'man'):0.045454545454545456
# ('man', 'king'):0.047619047619047616
# ('king', 'endless'):0.1
# ('endless', 'sea'):0.5
# ('sea', 'mediocr'):1.0
# ('mediocr', 'cape'):0.5
# ('cape', 'lick'):1.0
# ('lick', 'releas'):1.0
# ('releas', 'everi'):0.3333333333333333
# ('everi', 'year'):0.07142857142857142
# ('year', 'joke'):0.05263157894736842
# ('joke', 'obvious'):0.007575757575757576
# ('obvious', 'look'):0.3333333333333333
# ('like', 'masterpiec'):0.017241379310344827
# ('masterpiec', 'comparison'):0.06666666666666667
# ('comparison', 'movi'):0.25
# ('movi', 'memor'):0.00558659217877095
# ('memor', 'clever'):0.2
# ('clever', 'fanboy'):1.0
# ('fanboy', 'claim'):1.0
# ('claim', 'still'):0.16666666666666666
# ('still', 'mesmer'):0.1
# ('mesmer', 'passion'):0.2
# ('passion', 'reaction'):0.5
# ('reaction', 'everyon'):1.0
# ('everyon', 'seem'):0.058823529411764705
# ('seem', 'joke'):0.043478260869565216
# ('joke', 'act'):0.007575757575757576
# ('act', 'sort'):0.03125
# ('sort', 'cinemat'):0.5
# ('cinemat', 'antichrist'):0.16666666666666666
# ('antichrist', 'similar'):1.0
# ('similar', 'way'):0.16666666666666666
# ('way', 'lot'):0.02631578947368421
# ('peopl', 'react'):0.021739130434782608
# ('react', 'mere'):0.3333333333333333
# ('mere', 'exist'):0.3333333333333333
# ('exist', 'move'):0.14285714285714285
# ('move', 'like'):0.1
# ('like', 'da'):0.017241379310344827
# ('da', 'sinc'):1.0
# ('sinc', 'code'):0.14285714285714285
# ('code', 'last'):1.0
# ('last', 'temptat'):0.16666666666666666
# ('temptat', 'christ'):1.0
# ('christ', 'back'):1.0
# ('back', 'claim'):0.09090909090909091
# ('claim', 'would'):0.16666666666666666
# ('would', 'definit'):0.02564102564102564
# ('definit', 'inspir'):0.1
# ('inspir', 'act'):0.125
# ('act', 'violenc'):0.03125
# ('violenc', 'can'):0.1
# ('can', 'help'):0.08333333333333333
# ('help', 'find'):0.2
# ('find', 'iron'):0.1
# ('iron', 'movi'):0.14285714285714285
# ('movi', 'demon'):0.00558659217877095
# ('demon', 'rich'):0.3333333333333333
# ('rich', 'fair'):0.14285714285714285
# ('fair', 'total'):0.5
# ('total', 'deserv'):0.16666666666666666
# ('deserv', 'demonet'):0.07692307692307693
# ('demonet', 'still'):1.0
# ('still', 'manag'):0.1
# ('manag', 'get'):0.16666666666666666
# ('get', 'lot'):0.02040816326530612
# ('lot', 'love'):0.14285714285714285
# ('love', 'kind'):0.06666666666666667
# ('kind', 'reactionari'):0.07142857142857142
# ('reactionari', 'would'):1.0
# ('would', 'millionair'):0.02564102564102564
# ('millionair', 'pay'):1.0
# ('pay', 'higher'):0.5
# ('higher', 'tax'):0.5
# ('tax', 'also'):1.0
# ('also', 'lot'):0.041666666666666664
# ('love', 'peopl'):0.06666666666666667
# ('peopl', 'worship'):0.021739130434782608
# ('worship', 'tramp'):1.0
# ('tramp', 'god'):0.5
# ('god', 'despit'):0.3333333333333333
# ('despit', 'fact'):0.3
# ('fact', 'tramp'):0.08333333333333333
# ('tramp', 'coloni'):0.5
# ('coloni', 'close'):1.0
# ('close', 'person'):0.125
# ('person', 'trip'):0.06666666666666667
# ('trip', 'rich'):0.5
# ('rich', 'jerk'):0.14285714285714285
# ('jerk', 'grass'):0.2
# ('grass', 'arthur'):1.0
# ('arthur', 'subway'):0.02127659574468085
# ('subway', 'thoma'):0.5
# ('thoma', 'waynewho'):0.16666666666666666
# ('waynewho', 'way'):1.0
# ('way', 'isn'):0.02631578947368421
# ('isn', 'exactli'):0.08333333333333333
# ('exactli', 'portray'):0.5
# ('portray', 'sympathet'):0.07142857142857142
# ('sympathet', 'either'):0.25
# ('either', 'must'):0.14285714285714285
# ('must', 'consequ'):0.2
# ('consequ', 'careless'):1.0
# ('careless', 'review'):1.0
# ('review', 'hot'):0.037037037037037035
# ('hot', 'take'):0.5
# ('take', 'made'):0.04
# ('made', 'equal'):0.058823529411764705
# ('equal', 'careless'):0.3333333333333333
# ('review', 'focu'):0.037037037037037035
# ('focu', 'fact'):1.0
# ('fact', 'main'):0.08333333333333333
# ('charact', 'caucasian'):0.018518518518518517
# ('caucasian', 'male'):1.0
# ('male', 'fact'):1.0
# ('fact', 'poor'):0.08333333333333333
# ('poor', 'suffer'):0.16666666666666666
# ('suffer', 'bad'):0.16666666666666666
# ('bad', 'physic'):0.05
# ('physic', 'mental'):0.16666666666666666
# ('health', 'despit'):0.25
# ('fact', 'movi'):0.08333333333333333
# ('movi', 'clearli'):0.00558659217877095
# ('clearli', 'show'):0.25
# ('show', 'anyth'):0.058823529411764705
# ('anyth', 'privileg'):0.06666666666666667
# ('privileg', 'also'):1.0
# ('also', 'despit'):0.041666666666666664
# ('fact', 'event'):0.08333333333333333
# ('event', 'movi'):0.25
# ('movi', 'told'):0.00558659217877095
# ('told', 'perspect'):0.05263157894736842
# ('perspect', 'arthur'):0.25
# ('fleck', 'doesn'):0.045454545454545456
# ('mean', 'movi'):0.15384615384615385
# ('movi', 'glori'):0.00558659217877095
# ('glori', 'behavior'):0.5
# ('behavior', 'portray'):0.5
# ('portray', 'hero'):0.07142857142857142
# ('hero', 'also'):0.16666666666666666
# ('also', 'rememb'):0.041666666666666664
# ('rememb', 'plenti'):0.3333333333333333
# ('plenti', 'scene'):1.0
# ('scene', 'made'):0.041666666666666664
# ('made', 'clear'):0.058823529411764705
# ('clear', 'pretti'):0.3333333333333333
# ('pretti', 'delus'):0.3333333333333333
# ('delus', 'perspect'):1.0
# ('perspect', 'event'):0.25
# ('event', 'ambigu'):0.25
# ('ambigu', 'best'):0.5
# ('best', 'seem'):0.03125
# ('seem', 'modern'):0.043478260869565216
# ('modern', 'audienc'):0.2
# ('audienc', 'becom'):0.18181818181818182
# ('becom', 'allerg'):0.05263157894736842
# ('allerg', 'form'):1.0
# ('form', 'ambigu'):0.25
# ('ambigu', 'reason'):0.5
# ('reason', 'sometim'):0.2
# ('sometim', 'wonder'):0.3333333333333333
# ('wonder', 'batmanrel'):0.125
# ('batmanrel', 'medium'):1.0
# ('medium', 'seem'):0.25
# ('seem', 'bizarr'):0.043478260869565216
# ('bizarr', 'effect'):1.0
# ('effect', 'peopl'):0.1111111111111111
# ('peopl', 'dark'):0.021739130434782608
# ('knight', 'decent'):0.08333333333333333
# ('decent', 'movi'):0.5
# ('movi', 'treat'):0.00558659217877095
# ('treat', 'best'):0.16666666666666666
# ('best', 'thing'):0.03125
# ('thing', 'sinc'):0.047619047619047616
# ('sinc', 'slice'):0.14285714285714285
# ('slice', 'bread'):1.0
# ('bread', 'admit'):1.0
# ('admit', 'better'):0.3333333333333333
# ('better', 'anyth'):0.043478260869565216
# ('anyth', 'you'):0.06666666666666667
# ('you', 'also'):0.125
# ('also', 'think'):0.041666666666666664
# ('think', 'kind'):0.043478260869565216
# ('kind', 'soulless'):0.07142857142857142
# ('soulless', 'corpor'):1.0
# ('corpor', 'garag'):0.5
# ('garag', 'shouldn'):0.25
# ('shouldn', 'measur'):1.0
# ('measur', 'qualiti'):1.0
# ('qualiti', 'anyth'):0.2
# ('anyth', 'do'):0.06666666666666667
# ('do', 'still'):0.06666666666666667
# ('still', 'give'):0.1
# ('give', 'u'):0.05263157894736842
# ('u', 'compel'):0.05
# ('compel', 'movi'):0.3333333333333333
# ('want', 'quit'):0.030303030303030304
# ('hope', 'mean'):0.0625
# ('mean', 'origin'):0.07692307692307693
# ('stori', 'villain'):0.02702702702702703
# ('villain', 'made'):0.0625
# ('made', 'director'):0.058823529411764705
# ('director', 'hanov'):0.14285714285714285
# ('hanov', 'move'):0.3333333333333333
# ('move', 'could'):0.025
# ('could', 'even'):0.041666666666666664
# ('even', 'expect'):0.037037037037037035
# ('expect', 'review'):0.045454545454545456
# ('review', 'start'):0.037037037037037035
# ('start', 'drop'):0.1111111111111111
# ('drop', 'still'):0.3333333333333333
# ('still', 'want'):0.1
# ('want', 'sure'):0.030303030303030304
# ('would', 'like'):0.05128205128205128
# ('like', 'saw'):0.017241379310344827
# ('saw', 'way'):0.3333333333333333
# ('way', 'better'):0.02631578947368421
# ('better', 'thought'):0.043478260869565216
# ('thought', 'would'):0.23076923076923078
# ('would', 'wont'):0.02564102564102564
# ('wont', 'call'):0.2
# ('masterpiec', 'definit'):0.06666666666666667
# ('definit', 'top'):0.1
# ('top', '3'):0.25
# ('3', 'do'):0.2
# ('do', 'film'):0.06666666666666667
# ('film', 'time'):0.007352941176470588
# ('time', 'good'):0.017543859649122806
# ('good', 'there'):0.017241379310344827
# ('there', 'hardli'):0.1
# ('hardli', 'anyth'):0.5
# ('anyth', 'bad'):0.06666666666666667
# ('bad', 'joke'):0.1
# ('job', 'bring'):0.16666666666666666
# ('bring', 'charact'):0.1
# ('charact', 'life'):0.018518518518518517
# ('life', 'rather'):0.0625
# ('rather', 'typic'):0.16666666666666666
# ('typic', 'superherosupervillain'):0.2
# ('superherosupervillain', 'origin'):1.0
# ('stori', 'get'):0.02702702702702703
# ('get', 'see'):0.02040816326530612
# ('see', 'psycholog'):0.06060606060606061
# ('drama', 'horror'):0.1111111111111111
# ('horror', 'thank'):0.14285714285714285
# ('thank', 'god'):1.0
# ('god', 'got'):0.3333333333333333
# ('got', 'love'):0.14285714285714285
# ('love', 'gene'):0.06666666666666667
# ('gene', 'love'):0.1
# ('love', 'film'):0.13333333333333333
# ('like', 'infin'):0.017241379310344827
# ('infin', 'war'):1.0
# ('war', 'day'):0.5
# ('day', 'futur'):0.1111111111111111
# ('futur', 'past'):0.16666666666666666
# ('past', 'engag'):0.125
# ('engag', 'aim'):0.16666666666666666
# ('aim', 'spiderman'):1.0
# ('spiderman', 'occasion'):1.0
# ('occasion', 'realli'):1.0
# ('good', 'take'):0.017241379310344827
# ('take', 'break'):0.04
# ('break', 'film'):0.2
# ('kind', 'categori'):0.07142857142857142
# ('categori', 'film'):0.25
# ('like', 'unbreak'):0.017241379310344827
# ('unbreak', 'basic'):1.0
# ('basic', 'movi'):0.5
# ('movi', 'soiler'):0.00558659217877095
# ('soiler', 'ahead'):0.3333333333333333
# ('ahead', 'arthur'):1.0
# ('arthur', 'torment'):0.02127659574468085
# ('torment', 'societi'):0.5
# ('societi', 'mental'):0.038461538461538464
# ('unstabl', 'longer'):0.2
# ('longer', 'lose'):0.3333333333333333
# ('lose', 'mind'):0.5
# ('mind', 'constant'):0.08333333333333333
# ('constant', 'torment'):0.5
# ('torment', 'hell'):0.5
# ('hell', 'break'):0.3333333333333333
# ('break', 'loo'):0.2
# ('loo', 'that'):0.5
# ('that', 'movi'):0.05
# ('movi', 'show'):0.0111731843575419
# ('show', 'would'):0.058823529411764705
# ('would', 'quit'):0.05128205128205128
# ('quit', 'difficult'):0.07692307692307693
# ('difficult', 'give'):0.5
# ('give', 'realli'):0.05263157894736842
# ('plot', 'like'):0.047619047619047616
# ('like', 'sinc'):0.017241379310344827
# ('sinc', 'mani'):0.14285714285714285
# ('move', 'kind'):0.025
# ('kind', 'plot'):0.07142857142857142
# ('plot', 'aw'):0.047619047619047616
# ('aw', 'happi'):0.5
# ('happi', 'one'):0.25
# ('one', 'includ'):0.017241379310344827
# ('includ', 'complet'):0.3333333333333333
# ('complet', 'like'):0.14285714285714285
# ('like', 'movi'):0.017241379310344827
# ('movi', 'mean'):0.00558659217877095
# ('mean', 'screenplay'):0.07692307692307693
# ('screenplay', 'direct'):0.16666666666666666
# ('direct', 'work'):0.08333333333333333
# ('work', 'feel'):0.047619047619047616
# ('feel', 'arthur'):0.02564102564102564
# ('arthur', 'whenev'):0.02127659574468085
# ('whenev', 'movi'):0.5
# ('movi', 'ask'):0.00558659217877095
# ('ask', 'want'):0.3333333333333333
# ('want', 'root'):0.030303030303030304
# ('root', 'arthur'):0.2
# ('arthur', 'know'):0.02127659574468085
# ('know', 'mean'):0.058823529411764705
# ('mean', 'incred'):0.07692307692307693
# ('incred', 'terribl'):0.1
# ('terribl', 'thing'):0.5
# ('thing', 'happen'):0.047619047619047616
# ('happen', 'see'):0.07142857142857142
# ('see', 'slowli'):0.030303030303030304
# ('slowli', 'transit'):0.3333333333333333
# ('transit', 'joke'):0.25
# ('joke', 'complet'):0.007575757575757576
# ('complet', 'turn'):0.14285714285714285
# ('turn', 'joke'):0.125
# ('joke', 'worth'):0.007575757575757576
# ('worth', 'round'):0.14285714285714285
# ('round', 'applaus'):1.0
# ('applaus', 'feel'):0.3333333333333333
# ('feel', 'good'):0.02564102564102564
# ('good', 'well'):0.017241379310344827
# ('well', 'terrifi'):0.058823529411764705
# ('terrifi', 'action'):0.3333333333333333
# ('joke', 'whenev'):0.007575757575757576
# ('whenev', 'snap'):0.5
# ('snap', 'crazi'):0.5
# ('crazi', 'stuff'):0.2
# ('stuff', 'happen'):1.0
# ('happen', 'without'):0.07142857142857142
# ('get', 'soiler'):0.02040816326530612
# ('soiler', 'would'):0.3333333333333333
# ('would', 'say'):0.02564102564102564
# ('say', 'short'):0.02564102564102564
# ('short', 'mani'):0.16666666666666666
# ('mani', 'suitabl'):0.030303030303030304
# ('suitabl', 'line'):0.5
# ('line', 'make'):0.5
# ('make', 'sen'):0.05
# ('sen', 'whatev'):0.14285714285714285
# ('whatev', 'joke'):0.3333333333333333
# ('joke', 'psychopath'):0.007575757575757576
# ('psychopath', 'say'):0.16666666666666666
# ('say', 'realist'):0.02564102564102564
# ('realist', 'sane'):0.14285714285714285
# ('person', 'say'):0.06666666666666667
# ('say', 'obvious'):0.02564102564102564
# ('obvious', 'sick'):0.3333333333333333
# ('sick', 'terrifi'):0.125
# ('terrifi', 'gruesom'):0.3333333333333333
# ('gruesom', 'joke'):0.5
# ('joke', 'moment'):0.015151515151515152
# ('moment', 'proper'):0.125
# ('proper', 'joke'):0.25
# ('movi', 'clear'):0.00558659217877095
# ('clear', 'trailer'):0.3333333333333333
# ('trailer', 'there'):0.16666666666666666
# ('there', 'batman'):0.1
# ('batman', 'soiler'):0.04
# ('soiler', 'batman'):0.3333333333333333
# ('refer', 'support'):0.2
# ('support', 'movi'):0.2
# ('movi', 'could'):0.00558659217877095
# ('could', 'creat'):0.041666666666666664
# ('creat', 'mess'):0.125
# ('mess', 'might'):0.5
# ('might', 'felt'):0.1111111111111111
# ('like', 'shoehorn'):0.017241379310344827
# ('shoehorn', 'plotlin'):1.0
# ('plotlin', 'play'):1.0
# ('play', 'proper'):0.07142857142857142
# ('proper', 'support'):0.25
# ('support', 'main'):0.2
# ('main', 'stori'):0.09090909090909091
# ('stori', 'transit'):0.02702702702702703
# ('transit', 'arthur'):0.25
# ('arthur', 'joke'):0.02127659574468085
# ('joke', 'mix'):0.007575757575757576
# ('mix', 'good'):0.5
# ('good', 'thing'):0.034482758620689655
# ('thing', 'movi'):0.09523809523809523
# ('movi', 'wa'):0.00558659217877095
# ('wa', 'psychic'):0.14285714285714285
# ('psychic', 'horror'):0.5
# ('horror', 'vice'):0.14285714285714285
# ('vice', 'could'):0.5
# ('could', 'origin'):0.041666666666666664
# ('origin', 'like'):0.06666666666666667
# ('like', 'mani'):0.017241379310344827
# ('mani', 'other'):0.030303030303030304
# ('other', 'point'):0.1111111111111111
# ('point', 'similar'):0.06666666666666667
# ('similar', 'taxi'):0.3333333333333333
# ('driver', 'score'):0.058823529411764705
# ('score', 'want'):0.045454545454545456
# ('want', 'copi'):0.030303030303030304
# ('copi', 'past'):0.5
# ('past', 'taxi'):0.125
# ('driver', 'part'):0.058823529411764705
# ('make', 'obviou'):0.025
# ('obviou', 'movi'):0.5
# ('movi', 'inspir'):0.00558659217877095
# ('driver', 'necessarili'):0.058823529411764705
# ('necessarili', 'bad'):1.0
# ('bad', 'thing'):0.1
# ('movi', 'element'):0.00558659217877095
# ('element', 'homageish'):0.2
# ('homageish', 'way'):1.0
# ('way', 'look'):0.02631578947368421
# ('look', 'well'):0.038461538461538464
# ('well', 'made'):0.058823529411764705
# ('made', 'could'):0.058823529411764705
# ('could', 'slightli'):0.041666666666666664
# ('slightli', 'origin'):1.0
# ('origin', 'may'):0.06666666666666667
# ('may', 'feel'):0.125
# ('feel', 'bit'):0.02564102564102564
# ('bit', 'slow'):0.16666666666666666
# ('slow', 'peopl'):0.09090909090909091
# ('peopl', 'though'):0.021739130434782608
# ('though', 'worth'):0.125
# ('worth', 'time'):0.14285714285714285
# ('time', 'take'):0.017543859649122806
# ('take', 'controversi'):0.04
# ('controversi', 'happen'):0.3333333333333333
# ('happen', 'mormon'):0.07142857142857142
# ('mormon', 'might'):1.0
# ('might', 'watch'):0.1111111111111111
# ('film', 'caus'):0.007352941176470588
# ('caus', 'violenc'):0.2857142857142857
# ('violenc', 'happen'):0.1
# ('happen', 'violent'):0.07142857142857142
# ('violent', 'movi'):0.1
# ('even', 'though'):0.037037037037037035
# ('though', 'justifi'):0.125
# ('justifi', 'joke'):0.3333333333333333
# ('joke', 'action'):0.007575757575757576
# ('action', 'doesn'):0.07142857142857142
# ('doesn', 'show'):0.09090909090909091
# ('show', 'right'):0.058823529411764705
# ('right', 'speak'):0.1
# ('speak', 'violenc'):1.0
# ('violenc', 'psycholog'):0.1
# ('psycholog', 'compel'):0.1111111111111111
# ('compel', 'horror'):0.3333333333333333
# ('horror', 'le'):0.14285714285714285
# ('le', 'violent'):0.2
# ('violent', 'deadpool'):0.1
# ('deadpool', 'feel'):0.5
# ('feel', 'violent'):0.02564102564102564
# ('violent', 'seriou'):0.1
# ('seriou', 'movi'):1.0
# ('movi', 'clarif'):0.00558659217877095
# ('clarif', 'ride'):1.0
# ('ride', 'psychopath'):0.25
# ('psychopath', 'complet'):0.16666666666666666
# ('complet', 'total'):0.14285714285714285
# ('total', 'nonsens'):0.16666666666666666
# ('nonsens', 'conclus'):0.25
# ('conclus', 'must'):1.0
# ('must', 'watch'):0.2
# ('watch', 'dont'):0.023809523809523808
# ('dont', 'need'):0.07142857142857142
# ('need', 'follow'):0.045454545454545456
# ('follow', 'do'):1.0
# ('do', 'move'):0.06666666666666667
# ('move', 'understand'):0.025
# ('understand', 'expect'):0.08333333333333333
# ('expect', 'typic'):0.09090909090909091
# ('typic', 'superhero'):0.2
# ('superhero', 'action'):0.07142857142857142
# ('action', 'film'):0.07142857142857142
# ('film', 'chi'):0.007352941176470588
# ('chi', 'battl'):0.25
# ('battl', 'spectacl'):0.5
# ('spectacl', 'wrong'):0.5
# ('wrong', 'expect'):0.2
# ('expect', 'might'):0.045454545454545456
# ('might', 'ruin'):0.1111111111111111
# ('ruin', 'experi'):0.5
# ('experi', 'el'):0.14285714285714285
# ('el', 'found'):0.5
# ('found', 'better'):0.2
# ('better', 'dark'):0.043478260869565216
# ('knight', 'rise'):0.08333333333333333
# ('rise', 'take'):0.3333333333333333
# ('take', 'one'):0.04
# ('one', 'favorit'):0.017241379310344827
# ('favorit', 'gene'):0.5
# ('gene', 'woman'):0.1
# ('woman', 'movi'):0.25
# ('movi', 'replac'):0.00558659217877095
# ('replac', 'anoth'):1.0
# ('anoth', 'movi'):0.14285714285714285
# ('movi', 'list'):0.00558659217877095
# ('list', 'may'):1.0
# ('may', 'consid'):0.125
# ('consid', 'great'):0.125
# ('great', 'one'):0.05263157894736842
# ('one', 'last'):0.017241379310344827
# ('last', 'thing'):0.16666666666666666
# ('thing', 'peopl'):0.047619047619047616
# ('peopl', 'caus'):0.021739130434782608
# ('violenc', 'joke'):0.1
# ('joke', 'would'):0.007575757575757576
# ('would', 'equival'):0.02564102564102564
# ('equival', 'good'):1.0
# ('good', 'bad'):0.017241379310344827
# ('bad', 'ugli'):0.05
# ('ugli', 'inspir'):0.3333333333333333
# ('inspir', 'three'):0.125
# ('three', 'peopl'):0.1111111111111111
# ('peopl', 'gun'):0.021739130434782608
# ('gun', 'duel'):0.16666666666666666
# ('duel', 'gold'):1.0
# ('gold', 'rate'):1.0
# ('rate', 'score'):0.07692307692307693
# ('score', '1010'):0.045454545454545456
# ('1010', 'grade'):0.14285714285714285
# ('grade', 'went'):0.3333333333333333
# ('went', 'film'):0.25
# ('film', 'expect'):0.007352941176470588
# ('expect', 'allie'):0.045454545454545456
# ('allie', 'classic'):1.0
# ('classic', 'base'):0.3333333333333333
# ('base', 'review'):0.25
# ('review', 'read'):0.037037037037037035
# ('read', 'end'):0.3333333333333333
# ('end', 'watch'):0.06666666666666667
# ('watch', 'decent'):0.023809523809523808
# ('decent', 'film'):0.5
# ('film', 'overal'):0.007352941176470588
# ('overal', 'phoenix'):0.14285714285714285
# ('phoenix', 'outstand'):0.014084507042253521
# ('outstand', 'definit'):0.3333333333333333
# ('definit', 'part'):0.1
# ('part', 'feel'):0.07692307692307693
# ('like', 'you'):0.017241379310344827
# ('you', 'seen'):0.25
# ('seen', 'trailer'):0.043478260869565216
# ('trailer', 'you'):0.16666666666666666
# ('movi', 'best'):0.00558659217877095
# ('best', 'way'):0.03125
# ('way', 'describ'):0.02631578947368421
# ('describ', 'film'):1.0
# ('film', 'feel'):0.007352941176470588
# ('like', '2'):0.017241379310344827
# ('2', 'hour'):0.5
# ('hour', 'version'):0.1
# ('version', 'trailer'):0.2
# ('trailer', '2'):0.16666666666666666
# ('hour', 'rel'):0.1
# ('rel', 'common'):0.5
# ('common', 'aunti'):0.3333333333333333
# ('aunti', 'felt'):1.0
# ('felt', 'lot'):0.1
# ('lot', 'longerwhich'):0.07142857142857142
# ('longerwhich', 'isn'):1.0
# ('isn', 'good'):0.16666666666666666
# ('good', 'id'):0.017241379310344827
# ('say', 'much'):0.02564102564102564
# ('much', 'rental'):0.03125
# ('rental', 'theater'):1.0
# ('theater', 'movi'):1.0
# ('movi', 'kind'):0.00558659217877095
# ('kind', 'just'):0.07142857142857142
# ('just', 'charact'):1.0
# ('charact', 'suffer'):0.018518518518518517
# ('suffer', 'abus'):0.3333333333333333
# ('abus', 'good'):0.14285714285714285
# ('good', 'element'):0.017241379310344827
# ('element', 'plot'):0.2
# ('plot', 'audienc'):0.047619047619047616
# ('audienc', 'never'):0.09090909090909091
# ('never', 'suffer'):0.04
# ('abus', 'audienc'):0.14285714285714285
# ('audienc', 'need'):0.09090909090909091
# ('need', 'experi'):0.045454545454545456
# ('experi', 'catharsi'):0.14285714285714285
# ('catharsi', 'end'):1.0
# ('end', 'never'):0.06666666666666667
# ('never', 'happen'):0.04
# ('happen', 'joke'):0.07142857142857142
# ('film', 'huge'):0.007352941176470588
# ('huge', 'problem'):0.3333333333333333
# ('problem', 'never'):0.07692307692307693
# ('never', 'manag'):0.08
# ('manag', 'solv'):0.3333333333333333
# ('solv', 'want'):0.3333333333333333
# ('want', 'realist'):0.030303030303030304
# ('realist', 'tell'):0.14285714285714285
# ('tell', 'tale'):0.14285714285714285
# ('tale', 'innoc'):0.2
# ('innoc', 'abus'):1.0
# ('abus', 'individu'):0.14285714285714285
# ('individu', 'snap'):0.3333333333333333
# ('snap', 'also'):0.5
# ('also', 'want'):0.041666666666666664
# ('want', 'exist'):0.030303030303030304
# ('exist', 'within'):0.14285714285714285
# ('within', 'section'):0.25
# ('section', 'univers'):0.5
# ('univers', 'man'):0.1
# ('man', 'much'):0.047619047619047616
# ('much', 'abus'):0.03125
# ('abus', 'victim'):0.14285714285714285
# ('victim', 'creat'):0.3333333333333333
# ('creat', 'problem'):0.125
# ('problem', 'screenwrit'):0.07692307692307693
# ('screenwrit', 'never'):1.0
# ('solv', 'thu'):0.3333333333333333
# ('thu', 'joke'):0.5
# ('joke', 'come'):0.007575757575757576
# ('come', 'across'):0.05263157894736842
# ('across', 'sympathet'):1.0
# ('sympathet', 'charact'):0.25
# ('charact', 'first'):0.018518518518518517
# ('first', 'turn'):0.06666666666666667
# ('turn', 'viciou'):0.125
# ('viciou', 'killer'):1.0
# ('killer', 'toward'):0.2
# ('toward', 'end'):0.14285714285714285
# ('end', 'point'):0.06666666666666667
# ('point', 'everyon'):0.06666666666666667
# ('everyon', 'becom'):0.058823529411764705
# ('becom', 'confus'):0.05263157894736842
# ('confus', 'stop'):0.5
# ('stop', 'like'):0.16666666666666666
# ('like', 'redempt'):0.017241379310344827
# ('redempt', 'kind'):0.5
# ('kind', 'satisfi'):0.07142857142857142
# ('satisfi', 'emot'):0.3333333333333333
# ('emot', 'resolut'):0.09090909090909091
# ('resolut', 'brutal'):1.0
# ('brutal', 'end'):0.16666666666666666
# ('end', 'serv'):0.06666666666666667
# ('serv', 'purpos'):0.5
# ('purpos', 'wider'):1.0
# ('wider', 'franchis'):1.0
# ('franchis', 'doesn'):0.2
# ('doesn', 'deliv'):0.09090909090909091
# ('deliv', 'term'):0.16666666666666666
# ('term', 'end'):0.5
# ('end', 'charact'):0.06666666666666667
# ('charact', 'made'):0.018518518518518517
# ('made', 'sympath'):0.058823529411764705
# ('sympath', 'becom'):0.2
# ('becom', 'noth'):0.05263157894736842
# ('noth', 'caricatur'):0.1
# ('caricatur', 'silli'):1.0
# ('silli', 'superhero'):0.5
# ('superhero', 'univers'):0.07142857142857142
# ('univers', 'insult'):0.1
# ('insult', 'anyon'):1.0
# ('anyon', 'invest'):0.2
# ('invest', 'charact'):0.5
# ('charact', 'begin'):0.018518518518518517
# ('begin', 'audienc'):0.14285714285714285
# ('audienc', 'creat'):0.09090909090909091
# ('creat', 'also'):0.125
# ('also', 'one'):0.041666666666666664
# ('one', 'note'):0.017241379310344827
# ('note', 'disturb'):0.5
# ('disturb', 'anarchistcommunist'):0.058823529411764705
# ('anarchistcommunist', 'vice'):1.0
# ('vice', 'film'):0.5
# ('film', 'idea'):0.007352941176470588
# ('idea', 'better'):0.16666666666666666
# ('better', 'burn'):0.043478260869565216
# ('burn', 'world'):0.5
# ('world', 'allow'):0.0625
# ('allow', 'particular'):0.2
# ('particular', 'understand'):1.0
# ('understand', 'injustic'):0.08333333333333333
# ('injustic', 'go'):0.3333333333333333
# ('go', 'may'):0.09090909090909091
# ('may', 'piti'):0.125
# ('piti', 'joke'):0.25
# ('joke', 'hate'):0.007575757575757576
# ('hate', 'cynic'):0.14285714285714285
# ('cynic', 'wayn'):0.5
# ('wayn', 'wont'):0.07142857142857142
# ('wont', 'put'):0.2
# ('put', 'degener'):0.07692307692307693
# ('degener', 'mental'):1.0
# ('ill', 'clown'):0.045454545454545456
# ('clown', 'charg'):0.0625
# ('charg', 'angri'):1.0
# ('angri', 'mob'):0.25
# ('mob', 'want'):0.5
# ('want', 'burn'):0.030303030303030304
# ('burn', 'everyth'):0.5
# ('everyth', 'titl'):0.1111111111111111
# ('titl', 'worst'):0.2
# ('worst', 'possibl'):0.3333333333333333
# ('possibl', 'situat'):0.16666666666666666
# ('situat', 'solv'):0.25
# ('solv', 'wors'):0.3333333333333333
# ('wors', 'way'):0.16666666666666666
# ('way', 'possibl'):0.02631578947368421
# ('possibl', 'peopl'):0.16666666666666666
# ('like', 'wonder'):0.017241379310344827
# ('wonder', 'world'):0.125
# ('world', 'piec'):0.0625
# ('cap', 'today'):0.25
# ('today', 'go'):0.25
# ('go', 'wors'):0.09090909090909091
# ('wors', 'day'):0.16666666666666666
# ('day', 'deserv'):0.1111111111111111
# ('deserv', 'extinct'):0.07692307692307693
# ('extinct', 'one'):1.0
# ('move', 'year'):0.025
# ('year', '100'):0.05263157894736842
# ('100', 'oscar'):0.5
# ('oscar', 'worthi'):0.08695652173913043
# ('worthi', 'joaquin'):0.25
# ('deliv', 'one'):0.16666666666666666
# ('best', 'perform'):0.09375
# ('perform', 'give'):0.022222222222222223
# ('give', 'ever'):0.05263157894736842
# ('ever', 'scene'):0.07692307692307693
# ('scene', 'joaquin'):0.041666666666666664
# ('joaquin', 'portray'):0.016666666666666666
# ('portray', 'sociopath'):0.07142857142857142
# ('sociopath', 'mental'):0.5
# ('unstabl', 'man'):0.2
# ('man', 'transform'):0.047619047619047616
# ('transform', 'iron'):0.3333333333333333
# ('iron', 'joke'):0.14285714285714285
# ('joke', 'non'):0.007575757575757576
# ('non', 'grip'):0.5
# ('grip', 'accur'):0.5
# ('accur', 'realist'):1.0
# ('realist', 'touch'):0.14285714285714285
# ('touch', 'condit'):0.25
# ('condit', 'dark'):0.3333333333333333
# ('dark', 'disturb'):0.02857142857142857
# ('disturb', 'charact'):0.058823529411764705
# ('charact', 'piec'):0.037037037037037035
# ('piec', 'led'):0.2
# ('led', 'oscar'):0.5
# ('worthi', 'perform'):0.25
# ('realli', 'feel'):0.047619047619047616
# ('feel', 'bad'):0.02564102564102564
# ('bad', 'guy'):0.05
# ('guy', 'make'):0.25
# ('make', 'heartbreak'):0.025
# ('heartbreak', 'inevit'):1.0
# ('inevit', 'becom'):0.5
# ('becom', 'clown'):0.05263157894736842
# ('crime', 'know'):0.25
# ('know', 'love'):0.058823529411764705
# ('love', 'although'):0.06666666666666667
# ('although', 'were'):0.25
# ('were', 'never'):0.25
# ('never', 'seen'):0.08
# ('seen', 'like'):0.043478260869565216
# ('like', 'see'):0.017241379310344827
# ('see', 'suffer'):0.030303030303030304
# ('suffer', 'throughout'):0.16666666666666666
# ('throughout', 'movi'):0.25
# ('movi', 'point'):0.00558659217877095
# ('point', 'almost'):0.06666666666666667
# ('almost', 'foot'):0.25
# ('foot', 'him'):0.3333333333333333
# ('him', 'becom'):1.0
# ('becom', 'mass'):0.05263157894736842
# ('mass', 'murder'):0.3333333333333333
# ('murder', 'psyco'):0.5
# ('psyco', 'clown'):1.0
# ('clown', 'least'):0.0625
# ('least', 'make'):0.125
# ('feel', 'better'):0.02564102564102564
# ('better', 'happen'):0.043478260869565216
# ('happen', 'wish'):0.07142857142857142
# ('wish', 'could'):0.375
# ('could', 'avoid'):0.041666666666666664
# ('avoid', 'e'):0.5
# ('e', 'miss'):1.0
# ('miss', 'feel'):0.16666666666666666
# ('feel', 'care'):0.02564102564102564
# ('care', 'time'):0.25
# ('time', 'he'):0.017543859649122806
# ('he', 'joke'):0.16666666666666666
# ('joke', 'wish'):0.007575757575757576
# ('could', 'help'):0.041666666666666664
# ('help', 'there'):0.2
# ('there', 'lot'):0.1
# ('lot', 'great'):0.07142857142857142
# ('great', 'nod'):0.02631578947368421
# ('nod', 'greater'):0.2
# ('greater', 'batman'):0.5
# ('univers', 'yet'):0.1
# ('yet', 'movi'):0.25
# ('movi', 'self'):0.00558659217877095
# ('self', 'contain'):0.5
# ('contain', 'charact'):1.0
# ('piec', 'mark'):0.2
# ('mark', 'great'):0.5
# ('movi', 'act'):0.00558659217877095
# ('act', 'great'):0.03125
# ('great', 'plot'):0.02631578947368421
# ('plot', 'similar'):0.047619047619047616
# ('driver', 'brilliant'):0.058823529411764705
# ('brilliant', 'qualiti'):0.5
# ('show', 'dont'):0.058823529411764705
# ('need', 'chi'):0.045454545454545456
# ('chi', 'super'):0.25
# ('super', 'power'):0.16666666666666666
# ('power', 'great'):0.3333333333333333
# ('great', 'villain'):0.02631578947368421
# ('villain', 'superhero'):0.0625
# ('joke', 'everyon'):0.007575757575757576
# ('everyon', 'get'):0.058823529411764705
# ('movi', 'rise'):0.00558659217877095
# ('rise', 'joke'):0.3333333333333333
# ('joke', '1010'):0.007575757575757576
# ('1010', 'one'):0.14285714285714285
# ('one', 'worst'):0.017241379310344827
# ('worst', 'move'):0.3333333333333333
# ('move', 'ever'):0.025
# ('seen', 'ok'):0.043478260869565216
# ('ok', 'mayb'):0.5
# ('mayb', 'hope'):0.08333333333333333
# ('hope', 'surround'):0.0625
# ('surround', 'movi'):0.5
# ('movi', 'kill'):0.00558659217877095
# ('kill', 'masterpiec'):0.2
# ('masterpiec', 'ok'):0.06666666666666667
# ('ok', 'film'):0.5
# ('film', 'one'):0.029411764705882353
# ('one', 'star'):0.034482758620689655
# ('star', 'way'):0.1111111111111111
# ('way', 'mani'):0.02631578947368421
# ('mani', 'wa'):0.030303030303030304
# ('wa', 'actual'):0.14285714285714285
# ('actual', 'agre'):0.08333333333333333
# ('agre', 'actual'):0.3333333333333333
# ('actual', 'critic'):0.08333333333333333
# ('critic', 'grade'):0.1111111111111111
# ('grade', 'film'):0.3333333333333333
# ('film', 'honestli'):0.007352941176470588
# ('honestli', 'peopl'):0.2
# ('peopl', 'rate'):0.021739130434782608
# ('rate', 'movi'):0.07692307692307693
# ('masterpiec', 'need'):0.06666666666666667
# ('need', 'start'):0.09090909090909091
# ('start', 'watch'):0.1111111111111111
# ('watch', 'actual'):0.023809523809523808
# ('actual', 'masterpiec'):0.08333333333333333
# ('masterpiec', 'predict'):0.06666666666666667
# ('predict', 'indulg'):0.2
# ('indulg', 'simplist'):1.0
# ('simplist', 'good'):0.5
# ('way', 'could'):0.05263157894736842
# ('could', 'see'):0.041666666666666664
# ('see', 'everi'):0.030303030303030304
# ('everi', 'climax'):0.07142857142857142
# ('climax', '10'):1.0
# ('10', 'mind'):0.125
# ('mind', 'happen'):0.08333333333333333
# ('happen', 'good'):0.07142857142857142
# ('thing', '4'):0.047619047619047616
# ('4', 'score'):1.0
# ('score', '2cinematographi'):0.045454545454545456
# ('2cinematographi', 'part'):1.0
# ('part', 'direct'):0.07692307692307693
# ('direct', 'music'):0.08333333333333333
# ('music', 'choic'):0.2222222222222222
# ('choic', 'film'):0.2
# ('film', 'maker'):0.007352941176470588
# ('maker', 'need'):0.3333333333333333
# ('start', 'make'):0.1111111111111111
# ('one', 'prescreen'):0.017241379310344827
# ('prescreen', 'citi'):1.0
# ('citi', 'taken'):0.1
# ('taken', 'review'):0.25
# ('review', 'titl'):0.037037037037037035
# ('titl', 'give'):0.2
# ('give', 'torn'):0.05263157894736842
# ('torn', 'ye'):1.0
# ('ye', 'joaquin'):0.16666666666666666
# ('phoenix', 'alway'):0.014084507042253521
# ('alway', 'verit'):0.3333333333333333
# ('verit', 'action'):1.0
# ('action', 'talent'):0.07142857142857142
# ('talent', 'wast'):0.14285714285714285
# ('wast', 'role'):0.16666666666666666
# ('role', 'ye'):0.0625
# ('ye', 'phoenix'):0.16666666666666666
# ('portray', 'charact'):0.07142857142857142
# ('charact', 'riot'):0.018518518518518517
# ('riot', 'ye'):0.3333333333333333
# ('ye', 'stori'):0.16666666666666666
# ('stori', 'grip'):0.02702702702702703
# ('grip', 'also'):0.5
# ('also', 'necessari'):0.041666666666666664
# ('necessari', 'especi'):1.0
# ('especi', 'today'):0.16666666666666666
# ('today', 'seem'):0.25
# ('seem', 'mental'):0.043478260869565216
# ('ill', 'run'):0.045454545454545456
# ('run', 'rampart'):0.25
# ('rampart', 'ye'):0.5
# ('ye', 'tone'):0.16666666666666666
# ('tone', 'magnific'):0.25
# ('magnific', 'set'):1.0
# ('set', 'within'):0.1
# ('within', 'cinemat'):0.25
# ('cinemat', 'art'):0.16666666666666666
# ('art', 'direct'):0.14285714285714285
# ('direct', 'problem'):0.08333333333333333
# ('problem', 'way'):0.07692307692307693
# ('way', 'tie'):0.02631578947368421
# ('univers', 'particularli'):0.1
# ('particularli', 'common'):0.25
# ('common', 'differenti'):0.3333333333333333
# ('differenti', 'joke'):1.0
# ('joke', 'past'):0.007575757575757576
# ('past', 'still'):0.125
# ('still', 'problem'):0.1
# ('problem', 'make'):0.07692307692307693
# ('make', 'two'):0.025
# ('two', 'world'):0.16666666666666666
# ('world', 'merg'):0.0625
# ('merg', 'everyon'):1.0
# ('everyon', 'riot'):0.058823529411764705
# ('riot', 'violent'):0.3333333333333333
# ('violent', 'actor'):0.1
# ('actor', 'skill'):0.047619047619047616
# ('skill', 'isn'):0.3333333333333333
# ('isn', 'great'):0.08333333333333333
# ('great', 'laugh'):0.02631578947368421
# ('laugh', 'anyon'):0.09090909090909091
# ('anyon', 'joke'):0.2
# ('joke', 'nomin'):0.007575757575757576
# ('nomin', 'academi'):0.07692307692307693
# ('academi', 'award'):1.0
# ('award', 'joke'):0.16666666666666666
# ('joke', 'greet'):0.007575757575757576
# ('greet', 'dark'):0.5
# ('dark', 'first'):0.02857142857142857
# ('first', 'thing'):0.06666666666666667
# ('thing', 'know'):0.09523809523809523
# ('know', 'superhero'):0.058823529411764705
# ('movi', 'fact'):0.00558659217877095
# ('fact', 'hero'):0.08333333333333333
# ('hero', 'movi'):0.6666666666666666
# ('movi', 'unless'):0.00558659217877095
# ('unless', 'would'):1.0
# ('like', 'appli'):0.017241379310344827
# ('appli', 'label'):0.5
# ('label', 'singl'):1.0
# ('singl', 'mon'):0.25
# ('mon', 'live'):0.2
# ('live', 'hall'):0.09090909090909091
# ('hall', 'arthur'):1.0
# ('fleck', 'mr'):0.045454545454545456
# ('mr', 'fleck'):0.3333333333333333
# ('fleck', 'live'):0.045454545454545456
# ('live', 'home'):0.09090909090909091
# ('home', 'invalid'):0.3333333333333333
# ('invalid', 'mother'):1.0
# ('mother', 'wrung'):0.2
# ('wrung', 'renown'):1.0
# ('renown', 'apart'):1.0
# ('apart', 'work'):0.25
# ('work', 'clownforhir'):0.047619047619047616
# ('clownforhir', 'dream'):1.0
# ('dream', 'becom'):0.2
# ('becom', 'stand'):0.05263157894736842
# ('stand', 'comedian'):0.5
# ('comedian', 'depend'):0.3333333333333333
# ('depend', 'social'):1.0
# ('servic', 'suppli'):0.2
# ('suppli', '7'):1.0
# ('7', 'medit'):1.0
# ('medit', 'take'):0.5
# ('take', 'sinc'):0.04
# ('sinc', 'releas'):0.14285714285714285
# ('releas', 'abraham'):0.3333333333333333
# ('abraham', 'state'):1.0
# ('state', 'hospit'):0.25
# ('hospit', 'bleak'):1.0
# ('bleak', 'exist'):0.25
# ('exist', 'bleak'):0.14285714285714285
# ('bleak', 'time'):0.25
# ('time', 'bleak'):0.017543859649122806
# ('bleak', 'citi'):0.25
# ('citi', 'gothic'):0.1
# ('gothic', 'midst'):0.08333333333333333
# ('midst', 'garag'):1.0
# ('garag', 'worker'):0.25
# ('worker', 'strike'):0.25
# ('strike', 'super'):0.5
# ('super', 'rat'):0.16666666666666666
# ('rat', 'happi'):1.0
# ('happi', 'polit'):0.25
# ('polit', 'upheav'):0.3333333333333333
# ('upheav', 'grow'):1.0
# ('grow', 'chasm'):0.5
# ('chasm', 'class'):1.0
# ('class', 'get'):0.1111111111111111
# ('get', 'wors'):0.02040816326530612
# ('wors', 'arthur'):0.16666666666666666
# ('arthur', 'second'):0.02127659574468085
# ('second', 'thing'):0.3333333333333333
# ('know', 'standalon'):0.058823529411764705
# ('standalon', 'joke'):0.3333333333333333
# ('one', 'mostli'):0.017241379310344827
# ('mostli', 'unrel'):1.0
# ('unrel', 'connect'):1.0
# ('connect', 'previou'):0.5
# ('previou', 'project'):1.0
# ('project', 'fear'):1.0
# ('fear', 'colour'):0.25
# ('colour', 'clown'):1.0
# ('princ', 'charact'):0.3333333333333333
# ('charact', 'play'):0.018518518518518517
# ('play', 'voic'):0.07142857142857142
# ('voic', 'memor'):0.5
# ('memor', 'actor'):0.2
# ('actor', 'caesar'):0.047619047619047616
# ('caesar', 'robert'):1.0
# ('robert', 'jack'):0.2
# ('jack', 'nicholson'):1.0
# ('nicholson', 'heath'):0.6
# ('ledger', 'mark'):0.058823529411764705
# ('mark', 'famili'):0.5
# ('famili', 'dare'):0.5
# ('dare', 'let'):0.3333333333333333
# ('let', 'even'):0.16666666666666666
# ('even', 'each'):0.037037037037037035
# ('each', 'galifianaki'):0.5
# ('galifianaki', 'director'):1.0
# ('phillip', 'wrote'):0.034482758620689655
# ('wrote', 'script'):0.5
# ('script', 'scott'):0.125
# ('scott', 'silver'):1.0
# ('silver', 'best'):0.5
# ('best', 'known'):0.03125
# ('known', 'extrem'):0.2
# ('extrem', 'remedi'):0.3333333333333333
# ('remedi', 'hanov'):1.0
# ('hanov', 'franchis'):0.16666666666666666
# ('franchis', 'old'):0.2
# ('old', 'school'):1.0
# ('school', 'he'):0.3333333333333333
# ('he', 'bit'):0.16666666666666666
# ('bit', 'outsid'):0.16666666666666666
# ('outsid', 'usual'):0.3333333333333333
# ('usual', 'wheelhous'):0.2
# ('wheelhous', 'phillip'):1.0
# ('phillip', 'silver'):0.034482758620689655
# ('silver', 'seem'):0.5
# ('seem', 'embrac'):0.043478260869565216
# ('embrac', 'histori'):0.3333333333333333
# ('histori', 'charact'):0.25
# ('charact', 'also'):0.018518518518518517
# ('also', 'look'):0.041666666666666664
# ('look', 'textur'):0.038461538461538464
# ('textur', 'tone'):1.0
# ('tone', 'filmmak'):0.25
# ('filmmak', 'earlier'):0.5
# ('earlier', 'era'):1.0
# ('era', 'gritti'):0.5
# ('gritti', 'outcast'):0.25
# ('outcast', 'feel'):0.5
# ...
# ('tri', 'properli'):0.07142857142857142
# ('properli', 'comprehend'):1.0
# ('comprehend', 'problem'):1.0
# ('problem', 'in'):0.07692307692307693
# ('in', 'say'):0.1
# ('say', 'there'):0.02564102564102564
# ('there', 'solut'):0.1
# ('solut', 'would'):1.0
# ('would', 'requir'):0.02564102564102564
# ('requir', 'time'):0.3333333333333333
# ('time', 'polit'):0.017543859649122806
# ('polit', 'account'):0.3333333333333333
# ('account', 'use'):1.0
# ('use', 'clot'):0.1
# ('clot', 'tri'):1.0
# ('tri', 'fight'):0.07142857142857142
# ('fight', 'effort'):0.5
# ('effort', 'say'):0.5
# ('need', 'in'):0.045454545454545456
# ('in', 'talk'):0.1
# ('talk', 'join'):0.08333333333333333
# ('join', 'process'):0.5
# ('process', 'taxi'):1.0
# ('driver', 'clearli'):0.058823529411764705
# ('clearli', 'shape'):0.25
# ('shape', 'lot'):1.0
# ('lot', 'incred'):0.07142857142857142
# ('incred', 'effect'):0.1
# ('effect', 'film'):0.1111111111111111
# ('amaz', 'one'):0.08333333333333333
# ('one', 'first'):0.017241379310344827
# ('first', 'liveact'):0.06666666666666667
# ('liveact', 'version'):0.5
# ('version', 'least'):0.2
# ('least', 'last'):0.125
# ('last', '30'):0.16666666666666666
# ('30', 'year'):1.0
# ('year', 'grant'):0.05263157894736842
# ('grant', 'familiar'):0.5
# ('familiar', 'take'):0.25
# ('take', 'go'):0.04
# ('go', 'back'):0.09090909090909091
# ('back', 'understand'):0.09090909090909091
# ('understand', 'joke'):0.08333333333333333
# ('joke', 'end'):0.007575757575757576
# ('end', 'signatur'):0.06666666666666667
# ('signatur', 'look'):1.0
# ('look', 'realist'):0.038461538461538464
# ('realist', 'world'):0.14285714285714285
# ('world', 'vigil'):0.0625
# ('vigil', 'use'):1.0
# ('use', 'martial'):0.1
# ('martial', 'art'):1.0
# ('art', 'badg'):0.14285714285714285
# ('badg', 'would'):1.0
# ('would', 'felt'):0.02564102564102564
# ('felt', 'huge'):0.1
# ('huge', 'place'):0.3333333333333333
# ('place', 'in'):0.2
# ('in', 'thrill'):0.1
# ('thrill', 'noth'):0.2
# ('noth', 'like'):0.1
# ('like', 'appearsbruc'):0.017241379310344827
# ('appearsbruc', 'child'):1.0
# ('child', 'hope'):0.3333333333333333
# ('hope', 'remain'):0.0625
# ('remain', 'standalon'):1.0
# ('standalon', 'rather'):0.3333333333333333
# ('rather', 'joaquin'):0.16666666666666666
# ('joaquin', 'face'):0.016666666666666666
# ('face', 'batman'):0.25
# ('batman', 'keep'):0.04
# ('mind', 'love'):0.08333333333333333
# ('trilog', 'rare'):0.25
# ('rare', 'give'):1.0
# ('give', 'anyth'):0.05263157894736842
# ('anyth', 'highest'):0.06666666666666667
# ('highest', 'possibl'):1.0
# ('possibl', 'score'):0.16666666666666666
# ('score', 'mean'):0.045454545454545456
# ('movi', 'isn'):0.00558659217877095
# ('isn', 'perfectthat'):0.08333333333333333
# ('perfectthat', 'statu'):1.0
# ('statu', 'stripe'):0.5
# ('stripe', 'never'):1.0
# ('never', 'truli'):0.04
# ('truli', 'reach'):0.09090909090909091
# ('reach', 'weak'):0.5
# ('weak', 'within'):1.0
# ('within', 'greatli'):0.25
# ('greatli', 'outweigh'):1.0
# ('outweigh', 'posit'):1.0
# ('posit', 'that'):0.3333333333333333
# ('that', 'even'):0.05
# ('even', 'contest'):0.037037037037037035
# ('contest', 'come'):0.5
# ('come', 'can'):0.05263157894736842
# ('can', 'put'):0.08333333333333333
# ('put', 'word'):0.07692307692307693
# ('word', 'grate'):0.25
# ('grate', 'everyon'):1.0
# ('everyon', 'work'):0.058823529411764705
# ('work', 'abl'):0.047619047619047616
# ('abl', 'say'):0.25
# ('say', 'bloodi'):0.02564102564102564
# ('bloodi', 'violenc'):1.0
# ('violenc', 'littl'):0.1
# ('littl', 'immens'):0.1111111111111111
# ('immens', 'brutal'):0.5
# ('brutal', 'recommend'):0.16666666666666666
# ('recommend', 'everyon'):0.5
# ('everyon', 'passion'):0.058823529411764705
# ('passion', 'tubular'):0.5
# ('tubular', 'charact'):1.0
# ('charact', '1010'):0.018518518518518517
# ('1010', 'now'):0.14285714285714285
# ('now', 'honestli'):0.3333333333333333
# ('honestli', 'gutta'):0.2
# ('gutta', 'tell'):0.5
# ('tell', 'one'):0.14285714285714285
# ('seen', 'year'):0.043478260869565216
# ('year', 'cinematographi'):0.05263157894736842
# ('cinematographi', 'thump'):0.05
# ('thump', 'sadden'):1.0
# ('sadden', 'soundtrack'):1.0
# ('soundtrack', 'way'):0.3333333333333333
# ('way', 'org'):0.02631578947368421
# ('org', 'perform'):0.5
# ('phoenix', 'dark'):0.014084507042253521
# ('dark', 'revolv'):0.02857142857142857
# ('revolv', 'twist'):0.3333333333333333
# ('twist', 'now'):0.09090909090909091
# ('now', 'feel'):0.3333333333333333
# ('feel', 'deep'):0.02564102564102564
# ('deep', 'bone'):0.25
# ('bone', 'emot'):0.5
# ('emot', 'portray'):0.09090909090909091
# ('joke', 'alon'):0.007575757575757576
# ('alon', 'watch'):0.3333333333333333
# ('watch', 'hear'):0.023809523809523808
# ('hear', 'joke'):0.3333333333333333
# ('laugh', 'twist'):0.09090909090909091
# ('twist', 'evil'):0.09090909090909091
# ('evil', 'could'):0.16666666666666666
# ('could', 'hear'):0.08333333333333333
# ('hear', 'sad'):0.3333333333333333
# ('sad', 'come'):0.14285714285714285
# ('come', 'mouth'):0.05263157894736842
# ('mouth', 'could'):1.0
# ('hear', 'hour'):0.3333333333333333
# ('hour', 'practic'):0.1
# ('practic', 'laugh'):1.0
# ('laugh', 'alon'):0.09090909090909091
# ('alon', 'method'):0.3333333333333333
# ('method', 'act'):0.5
# ('act', 'perfectli'):0.03125
# ('perfectli', 'point'):0.25
# ('point', 'along'):0.06666666666666667
# ('along', 'subtl'):0.25
# ('subtl', 'gestur'):0.5
# ('gestur', 'danc'):1.0
# ('danc', 'done'):0.14285714285714285
# ('done', 'perfectli'):0.1111111111111111
# ('perfectli', 'joke'):0.25
# ('movi', 'psycholog'):0.00558659217877095
# ('psycholog', 'twist'):0.1111111111111111
# ('twist', 'made'):0.09090909090909091
# ('made', 'believ'):0.058823529411764705
# ('believ', 'immers'):0.09090909090909091
# ('immers', 'movi'):1.0
# ('total', 'shock'):0.16666666666666666
# ('shock', 'overwhelm'):0.16666666666666666
# ('overwhelm', 'everyth'):0.3333333333333333
# ('everyth', 'even'):0.1111111111111111
# ('even', 'left'):0.037037037037037035
# ('cinema', 'mindblown'):0.1
# ('mindblown', 'watch'):1.0
# ('cinema', 'half'):0.1
# ('half', 'cinema'):0.3333333333333333
# ('cinema', 'cheer'):0.1
# ('cheer', 'applaus'):0.3333333333333333
# ('applaus', 'certain'):0.3333333333333333
# ('certain', 'scene'):0.5
# ('scene', 'almost'):0.041666666666666664
# ('almost', 'entir'):0.25
# ('entir', 'patron'):0.14285714285714285
# ('patron', 'stay'):1.0
# ('stay', 'last'):0.3333333333333333
# ('last', 'credit'):0.16666666666666666
# ('credit', 'u'):0.25
# ('u', 'look'):0.05
# ('look', 'close'):0.038461538461538464
# ('close', 'even'):0.125
# ('even', 'joke'):0.037037037037037035
# ('joke', 'costum'):0.007575757575757576
# ('costum', 'revolv'):0.2
# ('revolv', 'chang'):0.3333333333333333
# ('chang', 'time'):0.16666666666666666
# ('time', 'time'):0.017543859649122806
# ('time', 'base'):0.017543859649122806
# ('base', 'journey'):0.25
# ('journey', 'experienc'):0.5
# ('experienc', 'look'):0.5
# ('look', 'final'):0.038461538461538464
# ('final', 'true'):0.14285714285714285
# ('true', 'form'):0.3333333333333333
# ('form', 'look'):0.25
# ('look', 'absolut'):0.038461538461538464
# ('absolut', 'stun'):0.2
# ('stun', 'excit'):0.2
# ('excit', 'dialogu'):0.2
# ('dialogu', 'told'):0.3333333333333333
# ('told', 'joke'):0.05263157894736842
# ('joke', 'heartcrush'):0.007575757575757576
# ('heartcrush', 'made'):1.0
# ('made', 'felt'):0.058823529411764705
# ('felt', 'bad'):0.1
# ('time', 'side'):0.017543859649122806
# ('side', 'evil'):0.3333333333333333
# ('evil', 'charact'):0.16666666666666666
# ('charact', 'mayb'):0.018518518518518517
# ('mayb', 'hero'):0.08333333333333333
# ('movi', 'know'):0.00558659217877095
# ('know', 'honestli'):0.058823529411764705
# ('honestli', 'u'):0.2
# ('u', 'watch'):0.1
# ('watch', 'one'):0.023809523809523808
# ('perform', 'u'):0.022222222222222223
# ('watch', 'long'):0.023809523809523808
# ('like', 'deserv'):0.017241379310344827
# ('deserv', 'watch'):0.07692307692307693
# ('watch', 'big'):0.023809523809523808
# ('big', 'screen'):0.3333333333333333
# ('screen', 'go'):0.16666666666666666
# ('go', 'find'):0.09090909090909091
# ('find', 'best'):0.1
# ('best', 'cinema'):0.03125
# ('cinema', 'town'):0.1
# ('town', 'enjoy'):1.0
# ('enjoy', 'wild'):0.08333333333333333
# ('wild', 'ride'):1.0
# ('ride', 'emot'):0.25
# ('emot', 'fear'):0.09090909090909091
# ('fear', 'anger'):0.25
# ('anger', 'satisfi'):0.3333333333333333
# ('satisfi', 'disturb'):0.3333333333333333
# ('disturb', 'got'):0.058823529411764705
# ('got', 'movi'):0.14285714285714285
# ('movi', 'humor'):0.00558659217877095
# ('humor', 'much'):0.5
# ('better', 'see'):0.043478260869565216
# ('see', 'first'):0.030303030303030304
# ('first', 'feel'):0.06666666666666667
# ('feel', 'piti'):0.02564102564102564
# ('piti', 'guy'):0.25
# ('guy', 'suffer'):0.25
# ('suffer', 'lack'):0.16666666666666666
# ('lack', 'charm'):0.14285714285714285
# ('charm', 'well'):0.5
# ('well', 'killer'):0.058823529411764705
# ('killer', 'heath'):0.2
# ('ledger', 'far'):0.058823529411764705
# ('better', 'notic'):0.043478260869565216
# ('notic', 'far'):0.2
# ('left', 'journalist'):0.07692307692307693
# ('journalist', 'new'):1.0
# ('york', 'time'):0.2
# ('time', 'roll'):0.017543859649122806
# ('roll', 'stone'):0.3333333333333333
# ('stone', 'guardian'):1.0
# ('guardian', 'rest'):1.0
# ('rest', 'despis'):0.14285714285714285
# ('despis', 'joke'):1.0
# ('joke', 'made'):0.007575757575757576
# ('made', 'differ'):0.058823529411764705
# ('differ', 'prevar'):0.058823529411764705
# ('prevar', 'fun'):1.0
# ('fun', 'meaningless'):0.2
# ('meaningless', 'nihilist'):0.5
# ('nihilist', 'danger'):0.5
# ('danger', 'provoc'):0.5
# ('provoc', 'real'):1.0
# ('real', 'reason'):0.08333333333333333
# ('reason', 'gang'):0.2
# ('gang', 'film'):1.0
# ('phillip', 'see'):0.034482758620689655
# ('see', 'fantasi'):0.030303030303030304
# ('fantasi', 'becom'):1.0
# ('becom', 'realiti'):0.05263157894736842
# ('realiti', 'america'):0.2
# ('america', 'far'):0.5
# ('left', 'run'):0.07692307692307693
# ('run', 'citi'):0.25
# ('citi', 'lo'):0.1
# ('lo', 'angel'):1.0
# ('angel', 'san'):1.0
# ('san', 'francisco'):1.0
# ('francisco', 'new'):1.0
# ('york', 'baltimor'):0.2
# ('baltimor', 'detroit'):1.0
# ('detroit', 'chicago'):1.0
# ('chicago', 'other'):1.0
# ('other', 'look'):0.1111111111111111
# ('like', 'gothic'):0.017241379310344827
# ('gothic', 'liter'):0.08333333333333333
# ('liter', 'overflow'):0.25
# ('overflow', 'filth'):1.0
# ('filth', 'drug'):1.0
# ('drug', 'admit'):1.0
# ('admit', 'mental'):0.3333333333333333
# ('mental', 'patient'):0.02857142857142857
# ('patient', 'roam'):1.0
# ('roam', 'free'):1.0
# ('free', 'bureaucrat'):0.5
# ('bureaucrat', 'run'):1.0
# ('run', 'enjoy'):0.25
# ('enjoy', 'support'):0.08333333333333333
# ('support', 'hypocrit'):0.2
# ('hypocrit', 'filmmak'):1.0
# ('filmmak', 'load'):0.5
# ('load', 'money'):1.0
# ('money', 'politician'):0.16666666666666666
# ('politician', 'busi'):1.0
# ('busi', 'leader'):0.3333333333333333
# ('leader', 'phillip'):1.0
# ('phillip', 'famou'):0.034482758620689655
# ('famou', 'none'):1.0
# ('none', 'inyourfac'):0.5
# ('inyourfac', 'comedi'):1.0
# ('comedi', 'rude'):0.08333333333333333
# ('rude', 'crude'):1.0
# ('crude', 'breakup'):1.0
# ('breakup', 'funni'):1.0
# ('funni', 'can'):0.3333333333333333
# ('not', 'make'):0.2
# ('like', 'anymor'):0.017241379310344827
# ('anymor', 'one'):1.0
# ('one', 'far'):0.017241379310344827
# ('left', 'speech'):0.07692307692307693
# ('speech', 'polic'):0.5
# ('polic', 'violent'):0.25
# ('violent', 'hatefil'):0.1
# ('hatefil', 'arrog'):1.0
# ('arrog', 'stupend'):1.0
# ('stupend', 'selfright'):1.0
# ('selfright', 'joke'):1.0
# ('joke', 'far'):0.007575757575757576
# ('left', 'dystopia'):0.07692307692307693
# ('dystopia', 'futur'):1.0
# ('futur', 'come'):0.16666666666666666
# ('come', 'soon'):0.05263157894736842
# ('soon', 'neighborhood'):1.0
# ('neighborhood', 'near'):1.0
# ('near', 'want'):0.25
# ('want', 'border'):0.030303030303030304
# ('border', 'elimin'):0.5
# ('elimin', 'jail'):1.0
# ('jail', 'open'):1.0
# ('open', 'lock'):0.3333333333333333
# ('lock', 'broken'):1.0
# ('broken', 'right'):0.2
# ('right', 'middl'):0.1
# ('middl', 'class'):0.5
# ('class', 'citizen'):0.1111111111111111
# ('citizen', 'taken'):0.5
# ('taken', 'allow'):0.25
# ('allow', 'mass'):0.2
# ('mass', 'beam'):0.3333333333333333
# ('beam', 'want'):1.0
# ('want', 'hard'):0.030303030303030304
# ('hard', 'work'):0.14285714285714285
# ('work', 'valu'):0.047619047619047616
# ('valu', 'driven'):0.16666666666666666
# ('driven', 'bedroom'):0.5
# ('bedroom', 'societi'):1.0
# ('societi', 'mutil'):0.038461538461538464
# ('mutil', 'defeat'):1.0
# ('defeat', 'destroy'):1.0
# ('destroy', 'ensu'):0.5
# ('ensu', 'mele'):1.0
# ('mele', 'dream'):1.0
# ('dream', 'underr'):0.2
# ('underr', 'marx'):1.0
# ('marx', 'vein'):1.0
# ('vein', 'stain'):1.0
# ('stain', 'hither'):1.0
# ('hither', 'modern'):1.0
# ('modern', 'socialist'):0.2
# ('socialist', 'great'):1.0
# ('film', 'monument'):0.007352941176470588
# ('monument', 'film'):1.0
# ('film', 'comedi'):0.007352941176470588
# ('comedi', 'horror'):0.08333333333333333
# ('kind', 'horror'):0.07142857142857142
# ('film', 'peopl'):0.007352941176470588
# ('peopl', 'pay'):0.021739130434782608
# ('pay', 'see'):0.5
# ('psycholog', 'horror'):0.1111111111111111
# ('horror', 'terror'):0.14285714285714285
# ('terror', 'alreadi'):1.0
# ('alreadi', 'made'):0.14285714285714285
# ('made', 'billion'):0.058823529411764705
# ('dollar', 'mani'):0.5
# ('peopl', 'cheer'):0.021739130434782608
# ('cheer', 'outcom'):0.3333333333333333
# ('outcom', 'other'):1.0
# ('other', 'see'):0.1111111111111111
# ('see', 'greatest'):0.030303030303030304
# ('greatest', 'valu'):1.0
# ('valu', 'look'):0.16666666666666666
# ('look', 'futur'):0.038461538461538464
# ('futur', 'ugghhh'):0.16666666666666666
# ('ugghhh', 'could'):1.0
# ('could', 'wrong'):0.041666666666666664
# ('wrong', 'ass'):0.2
# ('ass', 'joke'):1.0
# ('joke', 'major'):0.007575757575757576
# ('major', 'film'):0.5
# ('film', 'goe'):0.014705882352941176
# ('goe', 'film'):0.1
# ('film', 'review'):0.007352941176470588
# ('review', 'rate'):0.037037037037037035
# ('rate', 'abhorr'):0.07692307692307693
# ('abhorr', 'film'):1.0
# ('film', 'averag'):0.007352941176470588
# ('averag', '86'):0.2
# ('86', 'limb'):1.0
# ('limb', 'miss'):0.5
# ('miss', 'see'):0.16666666666666666
# ('see', '600'):0.030303030303030304
# ('600', 'thousand'):1.0
# ('thousand', 'film'):0.5
# ('goe', 'like'):0.1
# ('like', 'film'):0.017241379310344827
# ('film', 'receiv'):0.007352941176470588
# ('receiv', '11'):0.5
# ('nomin', 'mr'):0.07692307692307693
# ('mr', 'sullivan'):0.3333333333333333
# ('sullivan', 'hate'):1.0
# ('hate', 'consid'):0.14285714285714285
# ('consid', 'much'):0.125
# ('much', 'wast'):0.03125
# ('wast', 'time'):0.16666666666666666
# ('time', '1977'):0.017543859649122806
# ('1977', 'acclaim'):1.0
# ('acclaim', 'film'):1.0
# ('film', 'eraserhead'):0.007352941176470588
# ('eraserhead', 'joaquin'):1.0
# ('phoenix', 'nomin'):0.014084507042253521
# ('actor', 'oscar'):0.047619047619047616
# ('oscar', 'got'):0.043478260869565216
# ('got', 'bid'):0.14285714285714285
# ('bid', 'mayb'):1.0
# ('mayb', 'award'):0.08333333333333333
# ('award', 'medal'):0.16666666666666666
# ('medal', 'weight'):1.0
# ('weight', 'watch'):0.5
# ('watch', 'shed'):0.023809523809523808
# ('shed', '52'):1.0
# ('52', 'pound'):1.0
# ('pound', 'pathet'):0.5
# ('pathet', 'role'):1.0
# ('role', 'brood'):0.0625
# ('brood', 'mental'):1.0
# ('disturb', 'arthur'):0.058823529411764705
# ('fleck', 'ak'):0.045454545454545456
# ('ak', 'joke'):1.0
# ('joke', 'oscar'):0.007575757575757576
# ('nomin', 'chose'):0.07692307692307693
# ('chose', 'next'):1.0
# ('next', 'watch'):0.25
# ('watch', '2019'):0.023809523809523808
# ('film', 'upon'):0.007352941176470588
# ('hollywood', 'nomin'):0.16666666666666666
# ('nomin', 'ten'):0.07692307692307693
# ('ten', '10'):0.25
# ('10', 'scar'):0.125
# ('scar', 'year'):0.14285714285714285
# ('year', 'compet'):0.05263157894736842
# ('compet', 'joke'):0.3333333333333333
# ('joke', 'eleven'):0.007575757575757576
# ('eleven', '11'):1.0
# ('11', 'nomin'):0.25
# ('nomin', 'shock'):0.07692307692307693
# ('shock', 'joke'):0.16666666666666666
# ('joke', 'win'):0.007575757575757576
# ('win', 'scar'):0.09090909090909091
# ('scar', 'even'):0.14285714285714285
# ('even', 'shock'):0.037037037037037035
# ('shock', 'disappoint'):0.16666666666666666
# ('disappoint', 'upon'):0.5
# ('hollywood', 'win'):0.16666666666666666
# ('joke', 'compet'):0.007575757575757576
# ('compet', 'categori'):0.3333333333333333
# ('categori', 'let'):0.25
# ('let', 'see'):0.16666666666666666
# ('see', 'rate'):0.030303030303030304
# ('rate', '310'):0.07692307692307693
# ('310', 'hold'):1.0
# ('hold', 'true'):0.5
# ('true', 'oscar'):0.3333333333333333
# ('oscar', 'night'):0.043478260869565216
# ('night', 'joke'):0.5
# ('get', 'shut'):0.02040816326530612
# ('shut', 'would'):1.0
# ('would', 'anticip'):0.02564102564102564
# ('anticip', 'would'):0.5

# %%
whole_dataset = ''
index = []
i = 1
for line in df['After Lemmatization']:
  whole_dataset = whole_dataset + line
  value = 'Review-' + str(i)
  index.append(value)
  i += 1

# %%
import nltk
nltk.download('brown')
from textblob import TextBlob
noun_phrases = []
frequency = []
for line in df['After Lemmatization']:
  blob = TextBlob(line)
  for nouns in blob.noun_phrases:
    noun_phrases.append(nouns)
for word in noun_phrases:
  noun_phrases_freq = []
  for line in df['After Lemmatization']:
    noun_phrases_freq.append(line.count(word) / whole_dataset.count(word))
  frequency.append(noun_phrases_freq)
noun_phrases_df = pd.DataFrame(frequency).T
noun_phrases_df.columns = list(noun_phrases)
noun_phrases_df.index = index
noun_phrases_df
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
#             truli masterpiec  hollywood film  film decad truli  \
# Review-1                 1.0             1.0               1.0
# Review-2                 0.0             0.0               0.0
# Review-3                 0.0             0.0               0.0
# Review-4                 0.0             0.0               0.0
# Review-5                 0.0             0.0               0.0
# ...                      ...             ...               ...
# Review-120               0.0             0.0               0.0
# Review-121               0.0             0.0               0.0
# Review-122               0.0             0.0               0.0
# Review-123               0.0             0.0               0.0
# Review-124               0.0             0.0               0.0
#
#             comic book willingli realist  \
# Review-1                             1.0
# Review-2                             0.0
# Review-3                             0.0
# Review-4                             0.0
# Review-5                             0.0
# ...                                  ...
# Review-120                           0.0
# Review-121                           0.0
# Review-122                           0.0
# Review-123                           0.0
# Review-124                           0.0
#
#             direct cinematographi music act peopl surpris  \
# Review-1                                              1.0
# Review-2                                              0.0
# Review-3                                              0.0
# Review-4                                              0.0
# Review-5                                              0.0
# ...                                                   ...
# Review-120                                            0.0
# Review-121                                            0.0
# Review-122                                            0.0
# Review-123                                            0.0
# Review-124                                            0.0
#
#             violent necess messag societi reflect underappreciatedunrecognizedbulli peopl  \
# Review-1                                                  1.0
# Review-2                                                  0.0
# Review-3                                                  0.0
# Review-4                                                  0.0
# Review-5                                                  0.0
# ...                                                       ...
# Review-120                                                0.0
# Review-121                                                0.0
# Review-122                                                0.0
# Review-123                                                0.0
# Review-124                                                0.0
#
#             someth way show class differ  corrupt rich talent rule  \
# Review-1                             1.0                       1.0
# Review-2                             0.0                       0.0
# Review-3                             0.0                       0.0
# Review-4                             0.0                       0.0
# Review-5                             0.0                       0.0
# ...                                  ...                       ...
# Review-120                           0.0                       0.0
# Review-121                           0.0                       0.0
# Review-122                           0.0                       0.0
# Review-123                           0.0                       0.0
# Review-124                           0.0                       0.0
#
#             differ believ  multipl joke  ...  bid mayb award medal weight  \
# Review-1              1.0           1.0  ...                          0.0
# Review-2              0.0           0.0  ...                          0.0
# Review-3              0.0           0.0  ...                          0.0
# Review-4              0.0           0.0  ...                          0.0
# Review-5              0.0           0.0  ...                          0.0
# ...                   ...           ...  ...                          ...
# Review-120            0.0           0.0  ...                          0.0
# Review-121            0.0           0.0  ...                          0.0
# Review-122            0.0           0.0  ...                          0.0
# Review-123            0.0           0.0  ...                          0.0
# Review-124            0.0           0.0  ...                          1.0
#
#             pathet role brood  \
# Review-1                  0.0
# Review-2                  0.0
# Review-3                  0.0
# Review-4                  0.0
# Review-5                  0.0
# ...                       ...
# Review-120                0.0
# Review-121                0.0
# Review-122                0.0
# Review-123                0.0
# Review-124                1.0
#
#             mental disturb arthur fleck ak joke oscar nomin  \
# Review-1                                                0.0
# Review-2                                                0.0
# Review-3                                                0.0
# Review-4                                                0.0
# Review-5                                                0.0
# ...                                                     ...
# Review-120                                              0.0
# Review-121                                              0.0
# Review-122                                              0.0
# Review-123                                              0.0
# Review-124                                              1.0
#
#             time hollywood nomin  scar year compet joke  nomin shock joke  \
# Review-1                     0.0                    0.0               0.0
# Review-2                     0.0                    0.0               0.0
# Review-3                     0.0                    0.0               0.0
# Review-4                     0.0                    0.0               0.0
# Review-5                     0.0                    0.0               0.0
# ...                          ...                    ...               ...
# Review-120                   0.0                    0.0               0.0
# Review-121                   0.0                    0.0               0.0
# Review-122                   0.0                    0.0               0.0
# Review-123                   0.0                    0.0               0.0
# Review-124                   1.0                    1.0               1.0
#
#             shock disappoint  time hollywood  joke compet categori  \
# Review-1                 0.0        0.000000                   0.0
# Review-2                 0.0        0.333333                   0.0
# Review-3                 0.0        0.000000                   0.0
# Review-4                 0.0        0.000000                   0.0
# Review-5                 0.0        0.000000                   0.0
# ...                      ...             ...                   ...
# Review-120               0.0        0.000000                   0.0
# Review-121               0.0        0.000000                   0.0
# Review-122               0.0        0.000000                   0.0
# Review-123               0.0        0.000000                   0.0
# Review-124               1.0        0.666667                   1.0
#
#             true oscar night joke
# Review-1                      0.0
# Review-2                      0.0
# Review-3                      0.0
# Review-4                      0.0
# Review-5                      0.0
# ...                           ...
# Review-120                    0.0
# Review-121                    0.0
# Review-122                    0.0
# Review-123                    0.0
# Review-124                    1.0
#
# [124 rows x 1364 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (20 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
# Write your code here
import math
def tf_idf_value(sentence,word):
  size = len(sentence.split(" "))
  tf_value = sentence.count(word)/size
  idf_value = 0
  if(tf_value!=0):
    idf_value = math.log(size)/sentence.count(word)
  else:
    return 0;
  return tf_value*idf_value

sentences = df["Spelling Correction"].values.tolist()
tokens_list = set([j for i in sentences for j in i.split(" ")])
tf_idf = pd.DataFrame(tokens_list,columns=["token"])
count = 0
for i in sentences:
  tf_idf[str(count)] = tf_idf["token"].apply(lambda x : tf_idf_value(i,x))
  count+=1

tf_idf
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#            token         0         1         2         3         4         5  \
# 0                 0.055855  0.035297  0.110774  0.058163  0.081918  0.093937
# 1     redemption  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2      substance  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3      devillify  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4       brutally  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...          ...       ...       ...       ...       ...       ...       ...
# 2764        fire  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2765  hauntingly  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2766  adolescent  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2767    soulless  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2768         bad  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#         6         7         8  ...       114       115       116       117  \
# 0     0.0  0.070931  0.062052  ...  0.015598  0.070931  0.077095  0.140502
# 1     0.0  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2     0.0  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 3     0.0  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 4     0.0  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# ...   ...       ...       ...  ...       ...       ...       ...       ...
# 2764  0.0  0.000000  0.000000  ...  0.015598  0.000000  0.000000  0.000000
# 2765  0.0  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2766  0.0  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2767  0.0  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2768  0.0  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
#
#            118       119  120       121       122       123
# 0     0.023813  0.032879  0.0  0.149787  0.030795  0.041835
# 1     0.000000  0.000000  0.0  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.0  0.000000  0.000000  0.000000
# 3     0.000000  0.000000  0.0  0.000000  0.000000  0.000000
# 4     0.000000  0.000000  0.0  0.000000  0.000000  0.000000
# ...        ...       ...  ...       ...       ...       ...
# 2764  0.000000  0.000000  0.0  0.000000  0.000000  0.000000
# 2765  0.000000  0.000000  0.0  0.000000  0.000000  0.000000
# 2766  0.000000  0.000000  0.0  0.000000  0.000000  0.000000
# 2767  0.000000  0.000000  0.0  0.000000  0.000000  0.000000
# 2768  0.023813  0.032879  0.0  0.000000  0.000000  0.000000
#
# [2769 rows x 125 columns]

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
query_sentence = 'Shang-Chi and the Legend of the Ten Rings is an Action - Fantasy movie in which we watch a new era of Marvel Studios rise with Shang-Chi,the master of Kung Fu. He has to face his past involving him with the Ten Rings organization and crate his future accordingly.Finally, I have to say that "Shang-Chi and the Legend of the Ten Rings" is an amazing movie and I strongly recommend everyone to watch it, especially the fans of Marvel.'
X_list = word_tokenize(query_sentence)
sw = stopwords.words('english') 
X_set = {w for w in X_list if not w in sw}

# %%
def compute_vector(X_set, Y_set):
  rvector = X_set.union(Y_set)
  l1 =[];l2 =[]
  for w in rvector: 
      if w in X_set: l1.append(1)
      else: l1.append(0) 
      if w in Y_set: l2.append(1) 
      else: l2.append(0)
  return rvector, l1, l2

# %%
def compute_cosine(rvector, l1, l2):
  c = 0
  for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
  cosine = c / float((sum(l1)*sum(l2))**0.5) 
  return cosine

# %%
similarity_list = []
for sentence in df['Spelling Correction']:
  Y_list = word_tokenize(sentence)
  Y_set = {w for w in Y_list if not w in sw}
  rvector, l1, l2 = compute_vector(X_set, Y_set)
  try:
    similarity = compute_cosine(rvector, l1, l2)
  except ZeroDivisionError:
    similarity = 'None'
  similarity_list.append(similarity)
cosine_dataframe = pd.DataFrame(list(zip(df['Review'],similarity_list)), columns=['Reviews','Cosine Similarity'])
cosine_dataframe
# Out:
#                                                Reviews Cosine Similarity
# 0    Truly a masterpiece, The Best Hollywood film o...               0.0
# 1    I have seen Joker yesterday at Venice an early...          0.030268
# 2    I get why some people hate this . It's because...          0.063277
# 3    Let me start off by saying if Joaquin Phoneix ...          0.041757
# 4    Every once in a while a movie comes, that trul...          0.048479
# ..                                                 ...               ...
# 119  Wow I honestly gotta tell you, it's one of the...          0.030528
# 120                                                                 None
# 121  Disturbing. Just got out of the movie. My humo...          0.037716
# 122  You will notice the far left journalists: the ...          0.027888
# 123  Ugghhh how could I be so wrong in my assessmen...          0.017728
#
# [124 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own word embedding model**

# %% [markdown]
# (20 points). Use the data you collected for assignment two to build a word embedding model:
#
# (1) Train a 300-dimension word embedding (it can be word2vec, glove, ulmfit, bert, or others).
#
# (2) Visualize the word embedding model you created.
#
# Reference: https://machinelearningmastery.com/develop-word-embeddings-python-gensim/
#
# Reference: https://jaketae.github.io/study/word2vec/

# %%
# Write your code here
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:5 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (107.0.5304.87-0ubuntu11.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 5 not upgraded.
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages (4.6.0)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.7/dist-packages (from selenium) (2022.9.24)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.26.12)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.22.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.7/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (4.1.1)

# %%
from selenium import webdriver #importing selenium package
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv'
title_array = []
review_array = []
driver.get(link)
for num in range(4):
  driver.find_element(By.CLASS_NAME,"ipl-load-more__button").click()
  time.sleep(5)
  listOfTitle = driver.find_elements(By.CLASS_NAME, "title")
  listOfReviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(listOfTitle, listOfReviews):
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
df = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# Length of data frame is 124
#                                                  Title  \
# 0                             Perfect in every aspect.
# 1    A psychological study, rather than a superhero...
# 2                      Went for a second time to watch
# 3             JUST AMAZING. How does this movie exist.
# 4    Outstanding movie with a haunting performance ...
# ..                                                 ...
# 119  Masterpiece *Movie Of the Year* Best Actor - J...
# 120  The Joker is supposed to be a diabolical maste...
# 121                               Better if didn't saw
# 122                  Why Todd Phillipps Made This Film
# 123  A total letdown ... a hybrid film bordering be...
#
#                                                 Review
# 0    Truly a masterpiece, The Best Hollywood film o...
# 1    I have seen Joker yesterday at Venice an early...
# 2    I get why some people hate this . It's because...
# 3    Let me start off by saying if Joaquin Phoneix ...
# 4    Every once in a while a movie comes, that trul...
# ..                                                 ...
# 119  Wow I honestly gotta tell you, it's one of the...
# 120
# 121  Disturbing. Just got out of the movie. My humo...
# 122  You will notice the far left journalists: the ...
# 123  Ugghhh how could I be so wrong in my assessmen...
#
# [124 rows x 2 columns]

# %%
list2 = []
for i in df.index:
    y = str(df["Review"][i]).split()
    list2.append(y)

# %%
from gensim.models import Word2Vec
model2 = Word2Vec(list2, size = 300)
print(model2)
# Out:
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# Word2Vec(vocab=442, size=300, alpha=0.025)

# %%
words2 = list(model2.wv.vocab)
words2
# Out:
# ['a',
#  'The',
#  'Best',
#  'Hollywood',
#  'film',
#  'of',
#  'one',
#  'the',
#  'films',
#  'And',
#  'truly',
#  'to',
#  'comic',
#  'book',
#  'so',
#  'and',
#  'real',
#  'people',
#  'are',
#  'find',
#  'it',
#  'but',
#  "it's",
#  "It's",
#  'about',
#  'society',
#  'those',
#  'they',
#  'can',
#  'do',
#  'something',
#  'way',
#  'shows',
#  'class',
#  'how',
#  'rich',
#  'others',
#  'around',
#  'them',
#  'is',
#  'not',
#  "that's",
#  'what',
#  'makes',
#  'There',
#  'could',
#  'be',
#  'in',
#  'our',
#  'that',
#  'much',
#  'than',
#  'making',
#  'this',
#  'up',
#  'first',
#  'film.',
#  'A',
#  'I',
#  'have',
#  'seen',
#  'Joker',
#  'at',
#  'an',
#  'We',
#  'had',
#  'some',
#  'with',
#  'lead',
#  'definitely',
#  'was',
#  'worth',
#  'it.',
#  'cinema',
#  'as',
#  'because',
#  'far',
#  'from',
#  'or',
#  'movie,',
#  'most',
#  'genre',
#  'It',
#  'on',
#  'main',
#  'character,',
#  'Joaquin',
#  'Phoenix',
#  'does',
#  'take',
#  'say',
#  'both',
#  'good.',
#  'might',
#  'joker',
#  'while',
#  "Phoenix's",
#  'being',
#  'movie',
#  'superhero',
#  'movies',
#  'Dark',
#  'Knight',
#  'easily',
#  'good',
#  'very',
#  'film,',
#  'cinematography',
#  'cannot',
#  'feel',
#  'too',
#  'his',
#  'King',
#  'also',
#  'somewhat',
#  'am',
#  'see',
#  'more',
#  'by',
#  'Todd',
#  'This',
#  'best',
#  'only',
#  'should',
#  'get',
#  'why',
#  'hate',
#  'message',
#  'think',
#  'you',
#  'need',
#  'for',
#  "Arthur's",
#  'But',
#  'come',
#  'point',
#  'will',
#  'never',
#  'Phillips',
#  'just',
#  'amazing',
#  'enjoy',
#  'without',
#  'me',
#  'start',
#  'off',
#  'saying',
#  'if',
#  "doesn't",
#  'Oscar',
#  'movie.',
#  'Then',
#  'Oscars',
#  'every',
#  'review',
#  'story',
#  'he',
#  'takes',
#  'time',
#  'score',
#  'felt',
#  'like',
#  'Taxi',
#  'Driver',
#  'got',
#  'scenes',
#  'its',
#  'violent',
#  'all',
#  'going',
#  'needs',
#  'Director',
#  'performance',
#  'watch',
#  "won't",
#  'watching',
#  'seriously',
#  '-',
#  'emotions',
#  'same',
#  'time.',
#  'typical',
#  'psychological',
#  'single',
#  'character',
#  'ever',
#  'who',
#  'You',
#  'understand',
#  'character.',
#  'lot',
#  'us',
#  'become',
#  'better',
#  'everyone',
#  'make',
#  'other',
#  'sad',
#  'quite',
#  'win',
#  'u',
#  'really',
#  'acting',
#  '?',
#  '5',
#  'To',
#  'your',
#  'put',
#  'While',
#  "I've",
#  'many',
#  'down',
#  'often',
#  'great',
#  'effects',
#  'They',
#  "don't",
#  'mean',
#  'What',
#  'into',
#  'we',
#  'man',
#  'him',
#  'made',
#  'When',
#  'He',
#  'has',
#  'thought',
#  'Batman',
#  'getting',
#  'deeply',
#  'plot',
#  'talk',
#  'Heath',
#  'portrayal',
#  'Joker,',
#  'fact',
#  "isn't",
#  'no',
#  'DC',
#  'disturbed',
#  'right',
#  'If',
#  'dark',
#  'love',
#  'villain',
#  'bad',
#  'reviews',
#  'hyped',
#  'out',
#  'this,',
#  'actually',
#  'there',
#  'all.',
#  'even',
#  'left',
#  '10',
#  'here',
#  'tell',
#  "can't",
#  'through',
#  '(or',
#  'entire',
#  'then',
#  'you,',
#  'been',
#  'quality',
#  'live',
#  'little',
#  'where',
#  'would',
#  'seem',
#  'new',
#  'last',
#  'high',
#  'back',
#  'look',
#  'society,',
#  'mentally',
#  'ill',
#  'which',
#  'coming',
#  'away',
#  'looking',
#  'feeling',
#  'still',
#  'any',
#  'scene',
#  'these',
#  'times',
#  "wasn't",
#  'own',
#  'completely',
#  'universe',
#  'done',
#  "Don't",
#  'problem',
#  'feels',
#  'someone',
#  'told',
#  "I'm",
#  'trying',
#  'mental',
#  'illness',
#  'long',
#  'were',
#  'music',
#  'boring.',
#  'my',
#  'did',
#  'move',
#  'maybe',
#  'worse',
#  'social',
#  'life.',
#  'world',
#  'acting,',
#  'sound',
#  'script',
#  'deserves',
#  'story.',
#  'iconic',
#  '&',
#  'nothing',
#  'such',
#  'part',
#  '2',
#  'want',
#  'throughout',
#  'In',
#  'though',
#  '10/10',
#  'already',
#  'Good',
#  'when',
#  'despite',
#  'actor',
#  'Not',
#  'sure',
#  'anything',
#  'this.',
#  'kind',
#  'boring',
#  "That's",
#  'their',
#  'wonder',
#  'audience',
#  'him.',
#  'broken',
#  'goes',
#  'him,',
#  'well',
#  'known',
#  'director',
#  "didn't",
#  'all,',
#  'job',
#  'Arthur',
#  'Fleck',
#  'becoming',
#  'Joker.',
#  'worked',
#  'Murray',
#  'show',
#  'That',
#  'rest',
#  'slow',
#  'De',
#  'Niro',
#  'rating',
#  'less',
#  'disturbing',
#  'lacks',
#  'everything',
#  'Gotham',
#  'clown',
#  'role',
#  'Ledger',
#  '"The',
#  'realistic',
#  'know',
#  'New',
#  'unstable',
#  'gets',
#  'sick',
#  'Thomas',
#  'Wayne',
#  'three',
#  'work',
#  'actors',
#  'may',
#  'Just',
#  'world.',
#  'seems',
#  'name',
#  'rather',
#  'drama',
#  'person',
#  'evil',
#  'wants',
#  'enough',
#  'give',
#  'origin',
#  'hour',
#  "there's",
#  'things',
#  'means',
#  'not.',
#  'thing',
#  'films.',
#  'action',
#  'over',
#  'played',
#  'years',
#  'whole',
#  'characters',
#  'it,',
#  'mind',
#  'tries',
#  'For',
#  'Or',
#  'another',
#  'different',
#  'expecting',
#  '...',
#  'looks',
#  'cinematic',
#  'Fleck,',
#  'since',
#  'after',
#  ':',
#  "could've",
#  'horror',
#  "Joker's",
#  'becomes',
#  'wish',
#  'All',
#  'life',
#  'n',
#  'money',
#  'hard',
#  'legendary']

# %%
# fit a 2d PCA model to the vectors
from sklearn.decomposition import PCA

X = model2[model2.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   after removing the cwd from sys.path.

# %% [markdown]
# # **Question 4: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file



# Link: https://github.com/kavyamannam/haihua_INFO5731_Spring2020/blob/main/sentimental_analysis.csv
