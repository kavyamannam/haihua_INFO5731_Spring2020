# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyamannam/haihua_INFO5731_Spring2020/blob/main/In_class_exercise_02_09222022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The second In-class-exercise (09/22/2022, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:
Walmart reviews to know about customer satisfaction. 
The data that should be collected are the reviews that are given by the customers who shopped from Walmart and the customer reviews are taken from the website 
Huge amount of data is required and I have taken 1000 reviews.  

Steps for collecting and saving the data: 
1) To extract the data from the website beautiful Soup is used.  
2) By using the class name reviews are extracted and are appended to empty list 
3) A dataframe is created for the list




'''

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
import itertools
import lxml.html as LH
url = 'https://www.imdb.com/search/title/?title_type=feature'
imdb_url = "https://www.imdb.com"
response = requests.get(url)
movies_soup = BeautifulSoup(response.text, 'lxml')
movie_tags = movies_soup.find_all('a', attrs={'class': None})
movie_tags = [tag.attrs['href'] for tag in movie_tags 
              if tag.attrs['href'].startswith('/title') & tag.attrs['href'].endswith('/')]
movie_tags = list(dict.fromkeys(movie_tags))
movie_links = [imdb_url + tag + 'reviews' for tag in movie_tags]
def minMax(a):
      print(len(a))
      minpos = a.index(min(a))
      maxpos = a.index(max(a))
      return minpos, maxpos
def getReviews(soup):
    review_ratings = [tag.previous_element for tag in 
                           soup.find_all('span', attrs={'class': 'point-scale'})]
    if len(review_ratings) > 0:
      n_index, p_index = minMax(list(map(int, review_ratings)))
      review_list = soup.find_all('a', attrs={'class':'title'})
      reviews = ["https://www.imdb.com" + review['href'] for review in review_list]
      return reviews
    else:
      return None
def getSoup(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup
def getReviewText(review_url):
    soup = getSoup(review_url)
    tag = soup.find('div', attrs={'class': 'text show-more__control'})
    return tag.getText()
def getUserName(review_url):    
    soup = getSoup(review_url)
    tag = soup.find('h3')
    return list(tag.children)[0].getText()
def getMovieTitle(review_url):    
    soup = getSoup(review_url)
    tag = soup.find('h1')
    return list(tag.children)[1].getText()
def getReviewPostedDate(review_url):    
    soup = getSoup(review_url)
    tag = soup.find('div', attrs={'class': 'display-name-date'})
    return list(tag.children)[1].getText()
def getRatings(review_url):    
    soup = getSoup(review_url)
    tag = soup.find('div', attrs={'class': 'ipl-ratings-bar'})
    return list(tag.children)[1].getText()
movie_soups = getSoup(movie_links[0])
movie_review = getReviews(movie_soups)
imdb_review_texts = [getReviewText(url) for url in movie_review]
user_Names = [getUserName(url) for url in movie_review]
user_ratings = [getRatings(url) for url in movie_review]
posted_dates = [getReviewPostedDate(url) for url in movie_review]
data = {'User_Name': user_Names,
        'Review_text': imdb_review_texts,
        'Review_posted_time': posted_dates,
        'Star': user_ratings}
df = pd.DataFrame(data)
df.head(25)
# Out:
# 25
#               User_Name                                        Review_text  \
# 0             masonsaul  Thor: Love and Thunder does attempt to explore...
# 1           rockingruby  Christian Bale is great, Russell Crowe has a g...
# 2           blott2319-1  I think most people thought it was a big mista...
# 3            ryrymadrid  I'm a huge marvel fanboy, and hardly ever have...
# 4            TakeUpReel  ...Well, maybe not SNL-esque throughout the fu...
# 5    lawrencelawrence86  Fine seems to cover it, Disney has become fine...
# 6                gy-att  Movie is okay. Christian Bale is awesome, Chri...
# 7             mluinstra  There are so many things wrong with this film,...
# 8        PsychoBeard666  I can't be bothered typing an essay so I'll su...
# 9          afatedcircle  First off let's start by asking what gods Gorr...
# 10            FallenEye  Every million Thor: Love and Thunder makes, is...
# 11            FeastMode  This review will come off as very negative, bu...
# 12         UltraMaximal  Marvel films have never been for a smart audie...
# 13             dude5568  The film fails to meet the expectations of a g...
# 14  mindlessmoviemaster  This just another Disney Marvel film. All it i...
# 15          melcraig204  I feel like I've just watched a movie written ...
# 16        jiggler-88714  Everything is a joke, even when it shouldn't b...
# 17          mustangride  I am at a loss for words, it is childish but n...
# 18       akashdeb-94800  I never wrote negative review, but now it dese...
# 19       paularjyarishi  String of jokes and gags. Bland fight sequence...
# 20                Xstal  The Gods of Chore desecrate with poor humour, ...
# 21       Hopedoesnotdie  Wow as a HUGE! Marvel fan I'm shocked at how b...
# 22          daisukereds  ..and yet, this is all so very familiar.Lots o...
# 23          jtindahouse  I sometimes feel like Taika Waititi is wasting...
# 24          namob-43673  I had very low exceptions. Seeing how they dum...
#
#    Review_posted_time                Star
# 0         7 July 2022  \n\n\n\n\n\n6/10\n
# 1         7 July 2022  \n\n\n\n\n\n2/10\n
# 2        20 July 2022  \n\n\n\n\n\n3/10\n
# 3         9 July 2022  \n\n\n\n\n\n1/10\n
# 4        14 July 2022  \n\n\n\n\n\n3/10\n
# 5         8 July 2022  \n\n\n\n\n\n5/10\n
# 6        10 July 2022  \n\n\n\n\n\n5/10\n
# 7        13 July 2022  \n\n\n\n\n\n3/10\n
# 8         9 July 2022  \n\n\n\n\n\n4/10\n
# 9         8 July 2022  \n\n\n\n\n\n3/10\n
# 10       14 July 2022  \n\n\n\n\n\n3/10\n
# 11        8 July 2022  \n\n\n\n\n\n5/10\n
# 12        7 July 2022  \n\n\n\n\n\n1/10\n
# 13        8 July 2022  \n\n\n\n\n\n5/10\n
# 14        8 July 2022  \n\n\n\n\n\n1/10\n
# 15        6 July 2022  \n\n\n\n\n\n2/10\n
# 16        6 July 2022  \n\n\n\n\n\n3/10\n
# 17        6 July 2022  \n\n\n\n\n\n2/10\n
# 18        8 July 2022  \n\n\n\n\n\n1/10\n
# 19       13 July 2022  \n\n\n\n\n\n1/10\n
# 20   8 September 2022  \n\n\n\n\n\n3/10\n
# 21        8 July 2022  \n\n\n\n\n\n1/10\n
# 22        7 July 2022  \n\n\n\n\n\n5/10\n
# 23        6 July 2022  \n\n\n\n\n\n7/10\n
# 24        7 July 2022  \n\n\n\n\n\n2/10\n

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
from bs4 import BeautifulSoup
import requests, lxml, os, json
import pandas as pd
headers = {
    'User-agent':
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582"
}
params = {
  "q": "Information Science",
  "hl": "en",
}
google_link = requests.get('https://scholar.google.com/scholar', headers=headers, params = params).text
soup = BeautifulSoup(google_link, 'lxml')
for pdf in soup.select('.gs_or_ggsm a'):
  pdf_file_link = pdf['href']
  print(pdf_file_link)
  list_of_data = []
for result in soup.select('.gs_ri'):
  title_header = result.select_one('.gs_rt').text
  Information_publication = result.select_one('.gs_a').text
  abstract = result.select_one('.gs_rs').text
  try:
    version_of_articles = result.select_one('a~ a+ .gs_nph')['href']
  except:
    version_of_articles = None
  d = {
      'Title': title_header,
      'Authors/Venue/journal/conference being published/Year': Information_publication,
      'Abstract': abstract
  }
  list_of_data.append(d)
df = pd.DataFrame(list_of_data)
df.head()
# Out:
# https://www.marilia.unesp.br/Home/Instituicao/Docentes/EdbertoFerneda/k---artigo-01.pdf
# https://www.academia.edu/download/30771284/relevanceSaracevic.pdf
# https://discovery.ucl.ac.uk/id/eprint/10053533/3/Longley_version%202.0_Manfred%20geocomp_PAL.pdf
# http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.199.7788&rep=rep1&type=pdf
#                                                Title  \
# 0                   Information science: what is it?
# 1  The foundations of information science. Part I...
# 2       Information concepts for information science
# 3  [BOOK][B] Foundations of library and informati...
# 4  Relevance: A review of and a framework for the...
#
#   Authors/Venue/journal/conference being published/Year  \
# 0  H Borko - American documentation, 1968 - Wiley...
# 1  BC Brookes - Journal of information science, 1...
# 2  NJ Belkin - Journal of documentation, 1978 - e...
# 3                 RE Rubin - 2017 - books.google.com
# 4  T Saracevic - … of the American Society for in...
#
#                                             Abstract
# 0  … the American Society for Information Science...
# 1  … It is first argued that a niche for informat...
# 2  … , to problems within the theoretical structu...
# 3  … tensions in LIS education between informatio...
# 4  … -line information … information systems is s...

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
# You code here (Please add comments in the code):
import pandas as pd
import numpy as np
import tweepy
from tweepy import OAuthHandler

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)

# %%
import requests
import json

# %%
customer_key ="2Em7SxlX9jPMfL4x97r3zMO0x"
customer_secret = "sVbJzekKuiAgq83Y7gCwNVbSowqQokGVzWexKHl2cXIPceWtSd"
access_token ="1439767876962029572-uUMt8oWRyzj9ilE5zk4uYbL93sCMPT"
access_token_secret = "oydIGymn9bS767FVEMawE9GyGAnMmBJfaY2XXKmHnmliF"

# %%
auth = tweepy.OAuthHandler(customer_key, customer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
username =str(input("Enter user name\t"))
# Out:
# Enter user name	barackobama

# %%
data= tweepy.Cursor(api.user_timeline,id=username).items(1000)

tweets_list= [[username ,tweet.created_at, tweet.text] for tweet in data]

tweets= pd.DataFrame(tweets_list)
tweets.columns=['user_name','posted time','text']
tweets
# Out:
#        user_name         posted time  \
# 0    barackobama 2022-09-26 00:45:58
# 1    barackobama 2022-09-23 14:30:44
# 2    barackobama 2022-09-23 14:30:44
# 3    barackobama 2022-09-23 14:30:43
# 4    barackobama 2022-09-23 14:30:43
# ..           ...                 ...
# 995  barackobama 2019-06-14 21:58:49
# 996  barackobama 2019-06-11 16:15:32
# 997  barackobama 2019-06-10 15:52:11
# 998  barackobama 2019-06-07 14:27:18
# 999  barackobama 2019-06-06 22:57:02
#
#                                                   text
# 0    RT @ObamaFoundation: To all our Jewish friends...
# 1    This Banned Books Week, I hope you’ll take a m...
# 2    We also owe a debt of gratitude to the team at...
# 3    I’m grateful for people like Cameron who fough...
# 4    I'm thankful for leaders like Rebecca, one of ...
# ..                                                 ...
# 995  RT @ObamaFoundation: These young people want t...
# 996  The @USWNT is something to smile about. It was...
# 997  Six years ago, David Ortiz's spirit and resolv...
# 998  Last week, it was Virginia Beach. But day afte...
# 999  RT @ObamaFoundation: Courage is contagious. Wa...
#
# [1000 rows x 3 columns]
