# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyamannam/haihua_INFO5731_Spring2020/blob/main/In_class_exercise_03_10062022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (10/06/2022, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand text representation.

# %% [markdown]
# Question 1 (10 points): Describe an interesting text classification or text mining task and explain what kind of features might be useful for you to build the machine learning model. List your features and explain why these features might be helpful. You need to list at least five different types of features.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

One of the more fascinating text mining tasks is converting any website data or content into a usable format. 
removing stopwords - this helps in eliminating unimportant words, word frequency - TF-IDF algorithm is used to 
know the word frequency, it basically defines which word is most used in that set of data, 
number of sentences - this gives the number of sentences given, split - split is one of the main features used in 
machine learning models, it is the initial step performed data.

List of features:
    
1.Term frequency - Calculates the number of times a term appears in a document, allowing you to figure out what it's about.
2.N-grams - This term refers to a group of words that are used together to help understand the context and comparable 
concepts in a document.
3.Bag-of-words - Used to compare two text fields that include comparable words and generate a similar bag of words.
4.Named entity recognition - This technique is used to classify data into pre-defined categories, and it may be used
to solve a variety of real-world issues, such as extracting a specific category from a document.
5.Inverse document frequency - This is a metric for determining how often or uncommon a word is within the document. 
It is determined using the formula IDF = log(N/n), where N is the total number of documents and n denotes the number
of documents in which the word appeared.
'''

# %% [markdown]
# Question 2 (20 points): Write python code to extract these features you discussed above. You can collect a few sample text data for the feature extraction.

# %%
# You code here (Please add comments in the code):
import urllib.request as urllib2
from bs4 import BeautifulSoup

# %%
articleURL = "https://www.washingtonpost.com/news/the-switch/wp/2016/10/18/the-pentagons-massive-new-telescope-is-designed-to-track-space-junk-and-watch-out-for-killer-asteroids/"

# %%
#Download the web page
page = urllib2.urlopen(articleURL).read().decode('utf8','ignore') 
soup = BeautifulSoup(page,"lxml")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find('article')
# Out:
# <article class="grid-article mb-xxl-ns" data-qa="main"><div data-qa="lede-art" data-testid="lede-art"><div><div data-testid="video-wrapper"><figure class="pt-xs mb-md mr-auto-ns ml-auto-ns hide-for-print ml-neg-gutter mr-neg-gutter"><div class="w-100 aspect-custom" style="overflow:hidden;background-position:center;background-repeat:no-repeat;background-color:rgb(245, 245, 245);background-image:url(https://www.washingtonpost.com/wp-apps/imrs.php?src=https%3A%2F%2Fd1i4t8bqe7zgj6.cloudfront.net%2F10-18-2016%2Ft_1476804667714_name_20161018_DarpaPic.jpg&amp;w=960);background-size:contain;--aspect-height:0.5625;--aspect-width:1;filter:blur(5px);transition:filter .1s"></div><figcaption><div class="mt-xs mr-auto-ns ml-auto-ns left gray-dark font--subhead font-xxxs ml-gutter mr-gutter" data-qa="video-caption">The Space Surveillance Telescope offers improvements in determining the orbits of newly discovered objects and provides rapid observations of space events. (Video: DARPAtv)</div></figcap
# ...

# %%
soup.find('article').text
# Out:
# "The Space Surveillance Telescope offers improvements in determining the orbits of newly discovered objects and provides rapid observations of space events. (Video: DARPAtv)Gift ArticleShareThere are a lot of rocks flying around through space. Lots of debris, too. Old satellites, spent rocket boosters, even for a short while a spatula that got loose during a space shuttle mission in 2006. All of it swirling around in orbit, creating a bit of a traffic jam.WpGet the full experience.Choose your planArrowRightFor years, the Pentagon has been worried about the collisions that might be caused by an\xa0estimated 500,000 pieces of debris, taking out enormously valuable satellites and, in turn, creating even more debris. On Tuesday, the Defense Department\xa0took another significant step toward monitoring all of the cosmic junk swirling around in space, by delivering\xa0a gigantic new telescope capable of seeing small objects from very far away.Developed by the Defense Advanced Research Proj
# ...

# %%
text = ' '.join(map(lambda p: p.text, soup.find_all('article')))
text
# Out:
# "The Space Surveillance Telescope offers improvements in determining the orbits of newly discovered objects and provides rapid observations of space events. (Video: DARPAtv)Gift ArticleShareThere are a lot of rocks flying around through space. Lots of debris, too. Old satellites, spent rocket boosters, even for a short while a spatula that got loose during a space shuttle mission in 2006. All of it swirling around in orbit, creating a bit of a traffic jam.WpGet the full experience.Choose your planArrowRightFor years, the Pentagon has been worried about the collisions that might be caused by an\xa0estimated 500,000 pieces of debris, taking out enormously valuable satellites and, in turn, creating even more debris. On Tuesday, the Defense Department\xa0took another significant step toward monitoring all of the cosmic junk swirling around in space, by delivering\xa0a gigantic new telescope capable of seeing small objects from very far away.Developed by the Defense Advanced Research Proj
# ...

# %%
def getTextWaPo(url):
    page = urllib2.urlopen(url).read().decode('utf8')
    soup = BeautifulSoup(page,"lxml")
    text = ' '.join(map(lambda p: p.text, soup.find_all('article')))
    #return text.encode('ascii', errors='replace').replace("?"," ")
    return str(str(text).encode('ascii', errors='replace')).replace("?", " ")

# %%
text = getTextWaPo(articleURL)
text
# Out:
# 'b"The Space Surveillance Telescope offers improvements in determining the orbits of newly discovered objects and provides rapid observations of space events. (Video: DARPAtv)Gift ArticleShareThere are a lot of rocks flying around through space. Lots of debris, too. Old satellites, spent rocket boosters, even for a short while a spatula that got loose during a space shuttle mission in 2006. All of it swirling around in orbit, creating a bit of a traffic jam.WpGet the full experience.Choose your planArrowRightFor years, the Pentagon has been worried about the collisions that might be caused by an estimated 500,000 pieces of debris, taking out enormously valuable satellites and, in turn, creating even more debris. On Tuesday, the Defense Department took another significant step toward monitoring all of the cosmic junk swirling around in space, by delivering a gigantic new telescope capable of seeing small objects from very far away.Developed by the Defense Advanced Research Project Age
# ...

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation

# %%
import nltk
nltk.download('punkt')
sents = sent_tokenize(text)
sents
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['b"The Space Surveillance Telescope offers improvements in determining the orbits of newly discovered objects and provides rapid observations of space events.',
#  '(Video: DARPAtv)Gift ArticleShareThere are a lot of rocks flying around through space.',
#  'Lots of debris, too.',
#  'Old satellites, spent rocket boosters, even for a short while a spatula that got loose during a space shuttle mission in 2006.',
#  'All of it swirling around in orbit, creating a bit of a traffic jam.WpGet the full experience.Choose your planArrowRightFor years, the Pentagon has been worried about the collisions that might be caused by an estimated 500,000 pieces of debris, taking out enormously valuable satellites and, in turn, creating even more debris.',
# ...

# %%
word_sent = word_tokenize(text.lower())
word_sent
# Out:
# ['b',
#  "''",
#  'the',
#  'space',
#  'surveillance',
#  'telescope',
#  'offers',
#  'improvements',
#  'in',
#  'determining',
#  'the',
#  'orbits',
#  'of',
#  'newly',
#  'discovered',
#  'objects',
#  'and',
#  'provides',
#  'rapid',
#  'observations',
#  'of',
#  'space',
#  'events',
#  '.',
#  '(',
#  'video',
#  ':',
#  'darpatv',
#  ')',
#  'gift',
#  'articlesharethere',
#  'are',
#  'a',
#  'lot',
#  'of',
#  'rocks',
#  'flying',
#  'around',
#  'through',
#  'space',
#  '.',
#  'lots',
#  'of',
#  'debris',
#  ',',
#  'too',
#  '.',
#  'old',
#  'satellites',
#  ',',
#  'spent',
#  'rocket',
#  'boosters',
#  ',',
#  'even',
#  'for',
#  'a',
#  'short',
#  'while',
#  'a',
#  'spatula',
#  'that',
#  'got',
#  'loose',
#  'during',
#  'a',
#  'space',
#  'shuttle',
#  'mission',
#  'in',
#  '2006.',
#  'all',
#  'of',
#  'it',
#  'swirling',
#  'around',
#  'in',
#  'orbit',
#  ',',
#  'creating',
#  'a',
#  'bit',
#  'of',
#  'a',
#  'traffic',
#  'jam.wpget',
# ...

# %%
import nltk
nltk.download('stopwords')
_stopwords = set(stopwords.words('english') + list(punctuation) )
_stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
# ...

# %%
word_sent=[word for word in word_sent if word not in _stopwords]
word_sent
# Out:
# ['b',
#  "''",
#  'space',
#  'surveillance',
#  'telescope',
#  'offers',
#  'improvements',
#  'determining',
#  'orbits',
#  'newly',
#  'discovered',
#  'objects',
#  'provides',
#  'rapid',
#  'observations',
#  'space',
#  'events',
#  'video',
#  'darpatv',
#  'gift',
#  'articlesharethere',
#  'lot',
#  'rocks',
#  'flying',
#  'around',
#  'space',
#  'lots',
#  'debris',
#  'old',
#  'satellites',
#  'spent',
#  'rocket',
#  'boosters',
#  'even',
#  'short',
#  'spatula',
#  'got',
#  'loose',
#  'space',
#  'shuttle',
#  'mission',
#  '2006.',
#  'swirling',
#  'around',
#  'orbit',
#  'creating',
#  'bit',
#  'traffic',
#  'jam.wpget',
#  'full',
#  'experience.choose',
#  'planarrowrightfor',
#  'years',
#  'pentagon',
#  'worried',
#  'collisions',
#  'might',
#  'caused',
#  'estimated',
#  '500,000',
#  'pieces',
#  'debris',
#  'taking',
#  'enormously',
#  'valuable',
#  'satellites',
#  'turn',
#  'creating',
#  'even',
#  'debris',
#  'tuesday',
#  'defense',
# ...

# %%
from nltk.probability import FreqDist
freq = FreqDist(word_sent)
freq
# Out:
# FreqDist({'space': 16, 'telescope': 9, 'satellites': 8, 'objects': 7, 'debris': 7, 'orbit': 6, 'air': 6, 'force': 6, 'around': 4, 'small': 4, ...})

# %%
from heapq import nlargest

# %%
nlargest(10, freq, key=freq.get)
# Out:
# ['space',
#  'telescope',
#  'satellites',
#  'objects',
#  'debris',
#  'orbit',
#  'air',
#  'force',
#  'around',
#  'small']

# %%
from collections import defaultdict
ranking = defaultdict(int)

for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]
            
ranking
# Out:
# defaultdict(int,
#             {0: 63,
#              1: 28,
#              2: 8,
#              3: 37,
#              4: 66,
#              5: 182,
#              6: 27,
#              7: 31,
#              8: 18,
#              9: 25,
#              10: 55,
#              11: 128,
#              12: 36,
#              13: 68,
#              14: 107,
#              15: 30,
#              16: 64,
#              17: 23,
#              18: 23,
#              19: 83,
#              20: 30,
#              21: 5})

# %%
sents_idx = nlargest(5, ranking, key=ranking.get)
sents_idx
# Out:
# [5, 11, 14, 19, 13]

# %%
[sents[j] for j in sorted(sents_idx)]
# Out:
# ['On Tuesday, the Defense Department took another significant step toward monitoring all of the cosmic junk swirling around in space, by delivering a gigantic new telescope capable of seeing small objects from very far away.Developed by the Defense Advanced Research Project Agency, the Space Surveillance Telescope was formally transferred to the Air Force during a ceremony at White Sands Missile Base in New Mexico Tuesday.AdvertisementThe telescope is designed to monitor objects as small as softballs, in Geosynchonous orbit (GEO) some of the most important real estate in space.',
# ...

# %%
import pandas as pd
import numpy as np
data = pd.DataFrame(sents)

# %%
data.columns = ['sentense']
data
# Out:
#                                              sentense
# 0   b"The Space Surveillance Telescope offers impr...
# 1   (Video: DARPAtv)Gift ArticleShareThere are a l...
# 2                                Lots of debris, too.
# 3   Old satellites, spent rocket boosters, even fo...
# 4   All of it swirling around in orbit, creating a...
# 5   On Tuesday, the Defense Department took anothe...
# 6   At about 22,000 miles away, its orbit mirrors ...
# 7   That allows satellite television or communicat...
# 8   A volume of tens of thousands of oceans,  said...
# 9   But the telescope's ability to see  something ...
# 10  DARPA says the advanced technology in the mass...
# 11  It is also being used by NASA to monitor aster...
# 12  That's a critical capability for the U.S. mili...
# 13  The telescope would join another new space deb...
# 14  The radar system is going to be located on Kwa...
# 15  Instead of being a benign environment, the Pen...
# ...

# %%
#Upper characters in the reviews
data['upper'] = data['sentense'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
data[['sentense','upper']].head()
# Out:
#                                             sentense  upper
# 0  b"The Space Surveillance Telescope offers impr...      0
# 1  (Video: DARPAtv)Gift ArticleShareThere are a l...      0
# 2                               Lots of debris, too.      0
# 3  Old satellites, spent rocket boosters, even fo...      0
# 4  All of it swirling around in orbit, creating a...      0

# %%
# Getting Stopwords

from nltk.corpus import stopwords

import nltk
nltk.download('stopwords')
stop = stopwords.words('english')

data['stopwords'] = data['sentense'].apply(lambda x: len([x for x in x.split() if x in stop]))
data[['sentense','stopwords']].head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                             sentense  stopwords
# 0  b"The Space Surveillance Telescope offers impr...          5
# 1  (Video: DARPAtv)Gift ArticleShareThere are a l...          4
# 2                               Lots of debris, too.          1
# 3  Old satellites, spent rocket boosters, even fo...          8
# 4  All of it swirling around in orbit, creating a...         21

# %%
#hashtags in the reviews
data['hastags'] = data['sentense'].apply(lambda x: len([x for x in x.split() if x.startswith('#')]))
data[['sentense','hastags']].head()
# Out:
#                                             sentense  hastags
# 0  b"The Space Surveillance Telescope offers impr...        0
# 1  (Video: DARPAtv)Gift ArticleShareThere are a l...        0
# 2                               Lots of debris, too.        0
# 3  Old satellites, spent rocket boosters, even fo...        0
# 4  All of it swirling around in orbit, creating a...        0

# %%
#numerics in the reviews
data['numerics'] = data['sentense'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
data[['sentense','numerics']].head()
# Out:
#                                             sentense  numerics
# 0  b"The Space Surveillance Telescope offers impr...         0
# 1  (Video: DARPAtv)Gift ArticleShareThere are a l...         0
# 2                               Lots of debris, too.         0
# 3  Old satellites, spent rocket boosters, even fo...         0
# 4  All of it swirling around in orbit, creating a...         0

# %%
#Upper characters in the reviews
data['upper'] = data['sentense'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
data[['sentense','upper']].head()
# Out:
#                                             sentense  upper
# 0  b"The Space Surveillance Telescope offers impr...      0
# 1  (Video: DARPAtv)Gift ArticleShareThere are a l...      0
# 2                               Lots of debris, too.      0
# 3  Old satellites, spent rocket boosters, even fo...      0
# 4  All of it swirling around in orbit, creating a...      0

# %% [markdown]
# Question 3 (10 points): Use any of the feature selection methods mentioned in this paper "Deng, X., Li, Y., Weng, J., & Zhang, J. (2019). Feature selection for text classification: A review. Multimedia Tools & Applications, 78(3)." Select the most important features you extracted above, rank the features based on their importance in the descending order.

# %%
txt_classification = (data['sentense'][3:4]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
txt_classification.columns = ['words','tf']
txt_classification
# Out:
#           words  tf
# 0             a   3
# 1           Old   1
# 2          that   1
# 3            in   1
# 4       mission   1
# 5       shuttle   1
# 6         space   1
# 7        during   1
# 8         loose   1
# 9           got   1
# 10      spatula   1
# 11  satellites,   1
# 12        while   1
# 13        short   1
# 14          for   1
# 15         even   1
# 16    boosters,   1
# 17       rocket   1
# 18        spent   1
# 19        2006.   1

# %%
#ITF
import numpy as np
for i,word in enumerate(txt_classification['words']):
  txt_classification.loc[i, 'idf'] = np.log(data.shape[0]/(len(data[data['sentense'].str.contains(word)])))
  
txt_classification
# Out:
#           words  tf       idf
# 0             a   3  0.046520
# 1           Old   1  3.091042
# 2          that   1  1.011601
# 3            in   1  0.046520
# 4       mission   1  3.091042
# 5       shuttle   1  3.091042
# 6         space   1  0.693147
# 7        during   1  2.397895
# 8         loose   1  3.091042
# 9           got   1  3.091042
# 10      spatula   1  3.091042
# 11  satellites,   1  3.091042
# 12        while   1  3.091042
# 13        short   1  3.091042
# 14          for   1  1.704748
# 15         even   1  1.704748
# 16    boosters,   1  3.091042
# 17       rocket   1  3.091042
# 18        spent   1  3.091042
# 19        2006.   1  3.091042
